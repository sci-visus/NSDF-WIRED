# %% [markdown]
# # Identify missing hours between March 3, 2021 and February 10, 2024.
# #### We want to fill all gaps if possible.

# %% [markdown]
# #### Import necessary libraries

# %%
# to download latest firesmoke metadata netCDF file
import requests

# for loading netcdf files, for metadata
import xarray as xr
# for connecting OpenVisus framework to xarray
# from https://github.com/sci-visus/openvisuspy, 
from openvisuspy.xarray_backend import OpenVisusBackendEntrypoint

# Used for processing netCDF time data
import time
import datetime

# Used for numerical work
import numpy as np

# Used for loading data from pickle data
import pickle

# For working with pandas timestamps
import pandas as pd

# # For downloading from the internet, retrying netCDF files
# import wget

# For controlling via operating system
import os
import shutil

# Accessory for generating progress bar to see progress of loops
from tqdm import tqdm

# %% [markdown]
# ### 1. Determine the hours that failed to visualize in video, even though those hours are available in netCDF files/idx...

# %% [markdown]
# #### Import the issues found while generating visualizations of each timestep from IDX conversion and original netCDF files
#
# These were generated while running IDX conversion at `conversion`, v3.

# %%
with open("new_idx_issues.pkl", "rb") as input_file:
    idx_issues = pickle.load(input_file)

with open("new_netcdf_issues.pkl", "rb") as input_file:
    netcdf_issues = pickle.load(input_file)

# print how many issues there are
print(f'Number of IDX issues: {len(idx_issues)}')
print(f'Number of netCDF issues: {len(netcdf_issues)}')
# Out:
# Number of IDX issues: 444
# Number of netCDF issues: 444

# %% [markdown]
# #### Let's see where the IDX conversion and netCDF files agree on issues.
# If it's an issue in netCDF original file, it'll be an issue in IDX too. However converse is not necessarily true.

# %%
# make set of common datetime keys betwix idx and netcdf issues
common_dates = set(netcdf_issues.keys()).intersection(idx_issues.keys())

# get issues unique to each version of firesmoke data
idx_only_issues = set(idx_issues.keys()).difference(netcdf_issues.keys())
netcdf_only_issues = set(netcdf_issues.keys()).difference(idx_issues.keys())

# see how many such issues exist in these sets
print(f'Num. of issues IDX and netCDF agree on is {len(common_dates)}')
print(f'Num. of issues unique to IDX is {len(idx_only_issues)}')
print(f'Num. of issues unique to netCDF is {len(netcdf_only_issues)}')
# Out:
# Num. of issues IDX and netCDF agree on is 444
# Num. of issues unique to IDX is 0
# Num. of issues unique to netCDF is 0

# %% [markdown]
# #### Now let's see what's wrong with the array at the issues found above...
# I suspect these arrays are all zeros

# %%
netcdf_zeros = set()
idx_zeros = set()

for i in netcdf_issues:
    if np.all(netcdf_issues[i] == 0):
        netcdf_zeros.add(i)
        
for i in idx_issues:
    if np.all(idx_issues[i] == 0):
        idx_zeros.add(i)
        
print(f'Number of idx issues where array is all zeros is: {len(idx_zeros)}')
print(f'Number of netcdf issues where array is all zeros is: {len(netcdf_zeros)}')
# Out:
# Number of idx issues where array is all zeros is: 444
# Number of netcdf issues where array is all zeros is: 444

# %% [markdown]
# #### Let's get what dates failed i.e. are just all zeros

# %%
zero_hours = set()

for k in idx_issues.keys():
    zero_hours.add(pd.Timestamp(year=k.year, month=k.month, day=k.day, hour=k.hour))

# %%
print(f'there are {len(zero_hours)} hours whose data are all zeros')
# Out:
# there are 444 hours whose data are all zeros

# %% [markdown]
# ## 2. See what timesteps are unavailable due to netCDF files being missing
# #### This is the available conversion from our IDX conversion

# %% [markdown]
# #### Import data available from firesmoke_metadata.nc

# %%
# path to tiny NetCDF
url = 'https://github.com/sci-visus/NSDF-WIRED/raw/main/data/firesmoke_metadata_recent.nc'

# Download the file using requests
response = requests.get(url)
local_netcdf = 'firesmoke_metadata.nc'
with open(local_netcdf, 'wb') as f:
    f.write(response.content)

# open tiny netcdf with xarray and OpenVisus backend
ds = xr.open_dataset(local_netcdf, engine=OpenVisusBackendEntrypoint)
# Out:
# ov.LoadDataset(http://atlantis.sci.utah.edu/mod_visus?dataset=UBC_fire_smoke_BSC&cached=1)
# PM25
# Adding field  PM25 shape  [25053, 381, 1081, 21] dtype  float32 labels  ['time', 'ROW', 'COL', 'resolution'] Max Resolution  20

# %%
def parse_tflag(tflag):
    """
    Return the tflag as a datetime object
    :param list tflag: a list of two int32, the 1st representing date and 2nd representing time
    """
    # obtain year and day of year from tflag[0] (date)
    date = int(tflag[0])
    year = date // 1000 # first 4 digits of tflag[0]
    day_of_year = date % 1000 # last 3 digits of tflag[0]

    # create datetime object representing date
    final_date = datetime.datetime(year, 1, 1) + datetime.timedelta(days=day_of_year - 1)

    # obtain hour, mins, and secs from tflag[1] (time)
    time = int(tflag[1])
    hours = time // 10000 # first 2 digits of tflag[1]
    minutes = (time % 10000) // 100 # 3rd and 4th digits of tflag[1] 
    seconds = time % 100  # last 2 digits of tflag[1]

    # create final datetime object
    full_datetime = datetime.datetime(year, final_date.month, final_date.day, hours, minutes, seconds)
    return full_datetime

# %% [markdown]
# #### Create the set of the available hours in this dataset
# Including the hours with all zeros...

# %%
actual_tflag_set = set()

# get TFLAGs as datetime objects, friendlier, make a set, wanna see what's missing
for t in ds['TFLAG'].values:
    actual_tflag_set.add(parse_tflag(t[0]))

print(f'there are {len(actual_tflag_set)} hours available in firesmoke_metadata.nc dataset')
# Out:
# there are 25053 hours available in firesmoke_metadata.nc dataset

# %% [markdown]
# #### Create the set of all hours we would like, between dates 3/3/2021 - 2/10/2024

# %%
# Define the start and end dates
start_date = pd.Timestamp(datetime.datetime.strptime("20210303", "%Y%m%d"))
end_date = pd.Timestamp(datetime.datetime.strptime("20240210", "%Y%m%d"))

# Get all hours between the start and end dates
desired_tflag_set = {start_date + pd.Timedelta(hours=x) for x in range(int((end_date - start_date).total_seconds() // 3600) + 1)}

print(f'There are {len(desired_tflag_set)} hours between 3/3/21 and 2/10/24')
# Out:
# There are 25777 hours between 3/3/21 and 2/10/24

# %% [markdown]
# #### Determine what hours are apparently missing netCDF files using the sets above

# %%
missing_tflags = desired_tflag_set.difference(actual_tflag_set)

print(f'there are {len(missing_tflags)} missing hours from our dataset')
# Out:
# there are 747 missing hours from our dataset

# %%
len(zero_hours.intersection(missing_tflags))
# Out:
# 0

# %%
missing_tflags
# Out:
# {Timestamp('2021-03-03 00:00:00'),
#  Timestamp('2021-03-03 01:00:00'),
#  Timestamp('2021-03-03 02:00:00'),
#  Timestamp('2021-03-03 03:00:00'),
#  Timestamp('2021-03-03 04:00:00'),
#  Timestamp('2021-03-03 05:00:00'),
#  Timestamp('2021-03-03 06:00:00'),
#  Timestamp('2021-03-03 07:00:00'),
#  Timestamp('2021-03-03 08:00:00'),
#  Timestamp('2021-03-03 09:00:00'),
#  Timestamp('2021-03-03 10:00:00'),
#  Timestamp('2021-03-03 11:00:00'),
#  Timestamp('2021-03-03 12:00:00'),
#  Timestamp('2021-03-03 13:00:00'),
#  Timestamp('2021-03-03 14:00:00'),
#  Timestamp('2021-03-03 15:00:00'),
#  Timestamp('2021-03-03 16:00:00'),
#  Timestamp('2021-03-03 17:00:00'),
#  Timestamp('2021-03-03 18:00:00'),
#  Timestamp('2021-03-03 19:00:00'),
#  Timestamp('2021-03-03 20:00:00'),
#  Timestamp('2021-03-03 21:00:00'),
#  Timestamp('2021-03-03 22:00:00'),
#  Timestamp('2021-03-03 23:00:00'),
#  Timestamp('2022-02-16 00:00:00'),
#  Timestamp('2022-02-16 01:00:00'),
#  Timestamp('2022-02-16 02:00:00'),
#  Timestamp('2022-06-02 00:00:00'),
#  Timestamp('2022-06-02 01:00:00'),
#  Timestamp('2022-06-02 02:00:00'),
#  Timestamp('2022-06-02 03:00:00'),
#  Timestamp('2022-06-02 04:00:00'),
#  Timestamp('2022-06-02 05:00:00'),
#  Timestamp('2022-06-02 06:00:00'),
#  Timestamp('2022-06-02 07:00:00'),
#  Timestamp('2022-06-02 08:00:00'),
#  Timestamp('2022-06-02 09:00:00'),
#  Timestamp('2022-06-02 10:00:00'),
#  Timestamp('2022-06-02 11:00:00'),
#  Timestamp('2022-06-02 12:00:00'),
#  Timestamp('2022-06-02 13:00:00'),
#  Timestamp('2022-06-02 14:00:00'),
#  Timestamp('2022-06-02 15:00:00'),
#  Timestamp('2022-06-02 16:00:00'),
#  Timestamp('2022-06-02 17:00:00'),
#  Timestamp('2022-06-02 18:00:00'),
#  Timestamp('2022-06-02 19:00:00'),
#  Timestamp('2022-06-02 20:00:00'),
#  Timestamp('2022-06-02 21:00:00'),
#  Timestamp('2022-06-02 22:00:00'),
#  Timestamp('2022-06-02 23:00:00'),
#  Timestamp('2022-06-03 00:00:00'),
#  Timestamp('2022-06-03 01:00:00'),
#  Timestamp('2022-06-03 02:00:00'),
#  Timestamp('2022-06-03 03:00:00'),
#  Timestamp('2022-06-03 04:00:00'),
#  Timestamp('2022-06-03 05:00:00'),
#  Timestamp('2022-06-03 06:00:00'),
#  Timestamp('2022-06-03 07:00:00'),
#  Timestamp('2022-06-03 08:00:00'),
#  Timestamp('2022-06-03 09:00:00'),
#  Timestamp('2022-06-03 10:00:00'),
#  Timestamp('2022-06-03 11:00:00'),
#  Timestamp('2022-06-03 12:00:00'),
#  Timestamp('2022-06-03 13:00:00'),
#  Timestamp('2022-06-03 14:00:00'),
#  Timestamp('2022-06-03 15:00:00'),
#  Timestamp('2022-06-03 16:00:00'),
#  Timestamp('2022-06-03 17:00:00'),
#  Timestamp('2022-06-03 18:00:00'),
#  Timestamp('2022-06-03 19:00:00'),
#  Timestamp('2022-06-03 20:00:00'),
#  Timestamp('2022-06-03 21:00:00'),
#  Timestamp('2022-06-03 22:00:00'),
#  Timestamp('2022-06-03 23:00:00'),
#  Timestamp('2022-06-04 00:00:00'),
#  Timestamp('2022-06-04 01:00:00'),
#  Timestamp('2022-06-04 02:00:00'),
#  Timestamp('2022-06-04 03:00:00'),
#  Timestamp('2022-06-04 04:00:00'),
#  Timestamp('2022-06-04 05:00:00'),
#  Timestamp('2022-06-04 06:00:00'),
#  Timestamp('2022-06-04 07:00:00'),
#  Timestamp('2022-06-04 08:00:00'),
#  Timestamp('2022-06-04 09:00:00'),
#  Timestamp('2022-06-04 10:00:00'),
#  Timestamp('2022-06-04 11:00:00'),
#  Timestamp('2022-06-04 12:00:00'),
#  Timestamp('2022-06-04 13:00:00'),
#  Timestamp('2022-06-04 14:00:00'),
#  Timestamp('2022-06-04 15:00:00'),
#  Timestamp('2022-06-04 16:00:00'),
#  Timestamp('2022-06-04 17:00:00'),
#  Timestamp('2022-06-04 18:00:00'),
#  Timestamp('2022-06-04 19:00:00'),
#  Timestamp('2022-06-04 20:00:00'),
#  Timestamp('2022-06-04 21:00:00'),
#  Timestamp('2022-06-04 22:00:00'),
#  Timestamp('2022-06-04 23:00:00'),
#  Timestamp('2022-06-05 00:00:00'),
#  Timestamp('2022-06-05 01:00:00'),
#  Timestamp('2022-06-05 02:00:00'),
#  Timestamp('2022-06-05 03:00:00'),
#  Timestamp('2022-06-05 04:00:00'),
#  Timestamp('2022-06-05 05:00:00'),
#  Timestamp('2022-06-05 06:00:00'),
#  Timestamp('2022-06-05 07:00:00'),
#  Timestamp('2022-06-05 08:00:00'),
#  Timestamp('2022-06-05 09:00:00'),
#  Timestamp('2022-06-05 10:00:00'),
#  Timestamp('2022-06-05 11:00:00'),
#  Timestamp('2022-06-05 12:00:00'),
#  Timestamp('2022-06-05 13:00:00'),
#  Timestamp('2022-06-05 14:00:00'),
#  Timestamp('2022-06-05 15:00:00'),
#  Timestamp('2022-06-05 16:00:00'),
#  Timestamp('2022-06-05 17:00:00'),
#  Timestamp('2022-06-05 18:00:00'),
#  Timestamp('2022-06-05 19:00:00'),
#  Timestamp('2022-06-05 20:00:00'),
#  Timestamp('2022-06-05 21:00:00'),
#  Timestamp('2022-06-05 22:00:00'),
#  Timestamp('2022-06-05 23:00:00'),
#  Timestamp('2022-06-06 00:00:00'),
#  Timestamp('2022-06-06 01:00:00'),
#  Timestamp('2022-06-06 02:00:00'),
#  Timestamp('2022-06-06 03:00:00'),
#  Timestamp('2022-06-06 04:00:00'),
#  Timestamp('2022-06-06 05:00:00'),
#  Timestamp('2022-06-06 06:00:00'),
#  Timestamp('2022-06-06 07:00:00'),
#  Timestamp('2022-06-06 08:00:00'),
#  Timestamp('2022-06-06 09:00:00'),
#  Timestamp('2022-06-06 10:00:00'),
#  Timestamp('2022-06-06 11:00:00'),
#  Timestamp('2022-06-06 12:00:00'),
#  Timestamp('2022-06-06 13:00:00'),
#  Timestamp('2022-06-06 14:00:00'),
#  Timestamp('2022-06-06 15:00:00'),
#  Timestamp('2022-06-06 16:00:00'),
#  Timestamp('2022-06-06 17:00:00'),
#  Timestamp('2022-06-06 18:00:00'),
#  Timestamp('2022-06-06 19:00:00'),
#  Timestamp('2022-06-06 20:00:00'),
#  Timestamp('2022-06-06 21:00:00'),
#  Timestamp('2022-06-06 22:00:00'),
#  Timestamp('2022-06-06 23:00:00'),
#  Timestamp('2022-06-07 00:00:00'),
#  Timestamp('2022-06-07 01:00:00'),
#  Timestamp('2022-06-07 02:00:00'),
#  Timestamp('2022-06-07 03:00:00'),
#  Timestamp('2022-06-07 04:00:00'),
#  Timestamp('2022-06-07 05:00:00'),
#  Timestamp('2022-06-07 06:00:00'),
#  Timestamp('2022-06-07 07:00:00'),
#  Timestamp('2022-06-07 08:00:00'),
#  Timestamp('2022-06-07 09:00:00'),
#  Timestamp('2022-06-07 10:00:00'),
#  Timestamp('2022-06-07 11:00:00'),
#  Timestamp('2022-06-07 12:00:00'),
#  Timestamp('2022-06-07 13:00:00'),
#  Timestamp('2022-06-07 14:00:00'),
#  Timestamp('2022-06-07 15:00:00'),
#  Timestamp('2022-06-07 16:00:00'),
#  Timestamp('2022-06-07 17:00:00'),
#  Timestamp('2022-06-07 18:00:00'),
#  Timestamp('2022-06-07 19:00:00'),
#  Timestamp('2022-06-07 20:00:00'),
#  Timestamp('2022-06-07 21:00:00'),
#  Timestamp('2022-06-07 22:00:00'),
#  Timestamp('2022-06-07 23:00:00'),
#  Timestamp('2022-06-08 00:00:00'),
#  Timestamp('2022-06-08 01:00:00'),
#  Timestamp('2022-06-08 02:00:00'),
#  Timestamp('2022-06-08 03:00:00'),
#  Timestamp('2022-06-08 04:00:00'),
#  Timestamp('2022-06-08 05:00:00'),
#  Timestamp('2022-06-08 06:00:00'),
#  Timestamp('2022-06-08 07:00:00'),
#  Timestamp('2022-06-08 08:00:00'),
#  Timestamp('2022-06-08 09:00:00'),
#  Timestamp('2022-06-08 10:00:00'),
#  Timestamp('2022-06-08 11:00:00'),
#  Timestamp('2022-06-08 12:00:00'),
#  Timestamp('2022-06-08 13:00:00'),
#  Timestamp('2022-06-08 14:00:00'),
#  Timestamp('2022-06-08 15:00:00'),
#  Timestamp('2022-06-08 16:00:00'),
#  Timestamp('2022-06-08 17:00:00'),
#  Timestamp('2022-06-08 18:00:00'),
#  Timestamp('2022-06-08 19:00:00'),
#  Timestamp('2022-06-08 20:00:00'),
#  Timestamp('2022-06-08 21:00:00'),
#  Timestamp('2022-06-08 22:00:00'),
#  Timestamp('2022-06-08 23:00:00'),
#  Timestamp('2022-06-09 00:00:00'),
#  Timestamp('2022-06-09 01:00:00'),
#  Timestamp('2022-06-09 02:00:00'),
#  Timestamp('2022-06-09 03:00:00'),
#  Timestamp('2022-06-09 04:00:00'),
#  Timestamp('2022-06-09 05:00:00'),
#  Timestamp('2022-06-09 06:00:00'),
#  Timestamp('2022-06-09 07:00:00'),
#  Timestamp('2022-06-09 08:00:00'),
#  Timestamp('2022-06-09 09:00:00'),
#  Timestamp('2022-06-09 10:00:00'),
#  Timestamp('2022-06-09 11:00:00'),
#  Timestamp('2022-06-09 12:00:00'),
#  Timestamp('2022-06-09 13:00:00'),
#  Timestamp('2022-06-09 14:00:00'),
#  Timestamp('2022-06-09 15:00:00'),
#  Timestamp('2022-06-09 16:00:00'),
#  Timestamp('2022-06-09 17:00:00'),
#  Timestamp('2022-06-09 18:00:00'),
#  Timestamp('2022-06-09 19:00:00'),
#  Timestamp('2022-06-09 20:00:00'),
#  Timestamp('2022-06-09 21:00:00'),
#  Timestamp('2022-06-09 22:00:00'),
#  Timestamp('2022-06-09 23:00:00'),
#  Timestamp('2022-06-10 00:00:00'),
#  Timestamp('2022-06-10 01:00:00'),
#  Timestamp('2022-06-10 02:00:00'),
#  Timestamp('2022-06-10 03:00:00'),
#  Timestamp('2022-06-10 04:00:00'),
#  Timestamp('2022-06-10 05:00:00'),
#  Timestamp('2022-06-10 06:00:00'),
#  Timestamp('2022-06-10 07:00:00'),
#  Timestamp('2022-06-10 08:00:00'),
#  Timestamp('2022-06-10 09:00:00'),
#  Timestamp('2022-06-10 10:00:00'),
#  Timestamp('2022-06-10 11:00:00'),
#  Timestamp('2022-06-10 12:00:00'),
#  Timestamp('2022-06-10 13:00:00'),
#  Timestamp('2022-06-10 14:00:00'),
#  Timestamp('2022-06-10 15:00:00'),
#  Timestamp('2022-06-10 16:00:00'),
#  Timestamp('2022-06-10 17:00:00'),
#  Timestamp('2022-06-10 18:00:00'),
#  Timestamp('2022-06-10 19:00:00'),
#  Timestamp('2022-06-10 20:00:00'),
#  Timestamp('2022-06-10 21:00:00'),
#  Timestamp('2022-06-10 22:00:00'),
#  Timestamp('2022-06-10 23:00:00'),
#  Timestamp('2022-06-11 00:00:00'),
#  Timestamp('2022-06-11 01:00:00'),
#  Timestamp('2022-06-11 02:00:00'),
#  Timestamp('2022-06-11 03:00:00'),
#  Timestamp('2022-06-11 04:00:00'),
#  Timestamp('2022-06-11 05:00:00'),
#  Timestamp('2022-06-11 06:00:00'),
#  Timestamp('2022-06-11 07:00:00'),
#  Timestamp('2022-06-11 08:00:00'),
#  Timestamp('2022-06-11 09:00:00'),
#  Timestamp('2022-06-11 10:00:00'),
#  Timestamp('2022-06-11 11:00:00'),
#  Timestamp('2022-06-11 12:00:00'),
#  Timestamp('2022-06-11 13:00:00'),
#  Timestamp('2022-06-11 14:00:00'),
#  Timestamp('2022-06-11 15:00:00'),
#  Timestamp('2022-06-11 16:00:00'),
#  Timestamp('2022-06-11 17:00:00'),
#  Timestamp('2022-06-11 18:00:00'),
#  Timestamp('2022-06-11 19:00:00'),
#  Timestamp('2022-06-11 20:00:00'),
#  Timestamp('2022-06-11 21:00:00'),
#  Timestamp('2022-06-11 22:00:00'),
#  Timestamp('2022-06-11 23:00:00'),
#  Timestamp('2022-06-12 00:00:00'),
#  Timestamp('2022-06-12 01:00:00'),
#  Timestamp('2022-06-12 02:00:00'),
#  Timestamp('2022-06-12 03:00:00'),
#  Timestamp('2022-06-12 04:00:00'),
#  Timestamp('2022-06-12 05:00:00'),
#  Timestamp('2022-06-12 06:00:00'),
#  Timestamp('2022-06-12 07:00:00'),
#  Timestamp('2022-06-12 08:00:00'),
#  Timestamp('2022-06-12 09:00:00'),
#  Timestamp('2022-06-12 10:00:00'),
#  Timestamp('2022-06-12 11:00:00'),
#  Timestamp('2022-06-12 12:00:00'),
#  Timestamp('2022-06-12 13:00:00'),
#  Timestamp('2022-06-12 14:00:00'),
#  Timestamp('2022-06-12 15:00:00'),
#  Timestamp('2022-06-12 16:00:00'),
#  Timestamp('2022-06-12 17:00:00'),
#  Timestamp('2022-06-12 18:00:00'),
#  Timestamp('2022-06-12 19:00:00'),
#  Timestamp('2022-06-12 20:00:00'),
#  Timestamp('2022-06-12 21:00:00'),
#  Timestamp('2022-06-12 22:00:00'),
#  Timestamp('2022-06-12 23:00:00'),
#  Timestamp('2022-06-13 00:00:00'),
#  Timestamp('2022-06-13 01:00:00'),
#  Timestamp('2022-06-13 02:00:00'),
#  Timestamp('2022-06-13 03:00:00'),
#  Timestamp('2022-06-13 04:00:00'),
#  Timestamp('2022-06-13 05:00:00'),
#  Timestamp('2022-06-13 06:00:00'),
#  Timestamp('2022-06-13 07:00:00'),
#  Timestamp('2022-06-13 08:00:00'),
#  Timestamp('2022-06-13 09:00:00'),
#  Timestamp('2022-06-13 10:00:00'),
#  Timestamp('2022-06-13 11:00:00'),
#  Timestamp('2022-06-13 12:00:00'),
#  Timestamp('2022-06-13 13:00:00'),
#  Timestamp('2022-06-13 14:00:00'),
#  Timestamp('2022-06-13 15:00:00'),
#  Timestamp('2022-06-13 16:00:00'),
#  Timestamp('2022-06-13 17:00:00'),
#  Timestamp('2022-06-13 18:00:00'),
#  Timestamp('2022-06-13 19:00:00'),
#  Timestamp('2022-06-13 20:00:00'),
#  Timestamp('2022-06-13 21:00:00'),
#  Timestamp('2022-06-13 22:00:00'),
#  Timestamp('2022-06-13 23:00:00'),
#  Timestamp('2022-06-14 00:00:00'),
#  Timestamp('2022-06-14 01:00:00'),
#  Timestamp('2022-06-14 02:00:00'),
#  Timestamp('2022-06-14 03:00:00'),
#  Timestamp('2022-06-14 04:00:00'),
#  Timestamp('2022-06-14 05:00:00'),
#  Timestamp('2022-06-14 06:00:00'),
#  Timestamp('2022-06-14 07:00:00'),
#  Timestamp('2022-06-14 08:00:00'),
#  Timestamp('2022-06-14 09:00:00'),
#  Timestamp('2022-06-14 10:00:00'),
#  Timestamp('2022-06-14 11:00:00'),
#  Timestamp('2022-06-14 12:00:00'),
#  Timestamp('2022-06-14 13:00:00'),
#  Timestamp('2022-06-14 14:00:00'),
#  Timestamp('2022-06-14 15:00:00'),
#  Timestamp('2022-06-14 16:00:00'),
#  Timestamp('2022-06-14 17:00:00'),
#  Timestamp('2022-06-14 18:00:00'),
#  Timestamp('2022-06-14 19:00:00'),
#  Timestamp('2022-06-14 20:00:00'),
#  Timestamp('2022-06-14 21:00:00'),
#  Timestamp('2022-06-14 22:00:00'),
#  Timestamp('2022-06-14 23:00:00'),
#  Timestamp('2022-06-15 00:00:00'),
#  Timestamp('2022-06-15 01:00:00'),
#  Timestamp('2022-06-15 02:00:00'),
#  Timestamp('2022-06-15 03:00:00'),
#  Timestamp('2022-06-15 04:00:00'),
#  Timestamp('2022-06-15 05:00:00'),
#  Timestamp('2022-06-15 06:00:00'),
#  Timestamp('2022-06-15 07:00:00'),
#  Timestamp('2022-06-15 08:00:00'),
#  Timestamp('2022-06-15 09:00:00'),
#  Timestamp('2022-06-15 10:00:00'),
#  Timestamp('2022-06-15 11:00:00'),
#  Timestamp('2022-06-15 12:00:00'),
#  Timestamp('2022-06-15 13:00:00'),
#  Timestamp('2022-06-15 14:00:00'),
#  Timestamp('2022-06-15 15:00:00'),
#  Timestamp('2022-06-15 16:00:00'),
#  Timestamp('2022-06-15 17:00:00'),
#  Timestamp('2022-06-15 18:00:00'),
#  Timestamp('2022-06-15 19:00:00'),
#  Timestamp('2022-06-15 20:00:00'),
#  Timestamp('2022-06-15 21:00:00'),
#  Timestamp('2022-06-15 22:00:00'),
#  Timestamp('2022-06-15 23:00:00'),
#  Timestamp('2022-06-16 00:00:00'),
#  Timestamp('2022-06-16 01:00:00'),
#  Timestamp('2022-06-16 02:00:00'),
#  Timestamp('2022-06-16 03:00:00'),
#  Timestamp('2022-06-16 04:00:00'),
#  Timestamp('2022-06-16 05:00:00'),
#  Timestamp('2022-06-16 06:00:00'),
#  Timestamp('2022-06-16 07:00:00'),
#  Timestamp('2022-06-16 08:00:00'),
#  Timestamp('2022-06-16 09:00:00'),
#  Timestamp('2022-06-16 10:00:00'),
#  Timestamp('2022-06-16 11:00:00'),
#  Timestamp('2022-06-16 12:00:00'),
#  Timestamp('2022-06-16 13:00:00'),
#  Timestamp('2022-06-16 14:00:00'),
#  Timestamp('2022-06-16 15:00:00'),
#  Timestamp('2022-06-16 16:00:00'),
#  Timestamp('2022-06-16 17:00:00'),
#  Timestamp('2022-06-16 18:00:00'),
#  Timestamp('2022-06-16 19:00:00'),
#  Timestamp('2022-06-16 20:00:00'),
#  Timestamp('2022-06-16 21:00:00'),
#  Timestamp('2022-06-16 22:00:00'),
#  Timestamp('2022-06-16 23:00:00'),
#  Timestamp('2022-06-17 00:00:00'),
#  Timestamp('2022-06-17 01:00:00'),
#  Timestamp('2022-06-17 02:00:00'),
#  Timestamp('2022-06-17 03:00:00'),
#  Timestamp('2022-06-17 04:00:00'),
#  Timestamp('2022-06-17 05:00:00'),
#  Timestamp('2022-06-17 06:00:00'),
#  Timestamp('2022-06-17 07:00:00'),
#  Timestamp('2022-06-17 08:00:00'),
#  Timestamp('2022-06-17 09:00:00'),
#  Timestamp('2022-06-17 10:00:00'),
#  Timestamp('2022-06-17 11:00:00'),
#  Timestamp('2022-06-17 12:00:00'),
#  Timestamp('2022-06-17 13:00:00'),
#  Timestamp('2022-06-17 14:00:00'),
#  Timestamp('2022-06-17 15:00:00'),
#  Timestamp('2022-06-17 16:00:00'),
#  Timestamp('2022-06-17 17:00:00'),
#  Timestamp('2022-06-17 18:00:00'),
#  Timestamp('2022-06-17 19:00:00'),
#  Timestamp('2022-06-17 20:00:00'),
#  Timestamp('2022-06-17 21:00:00'),
#  Timestamp('2022-06-17 22:00:00'),
#  Timestamp('2022-06-17 23:00:00'),
#  Timestamp('2022-06-18 00:00:00'),
#  Timestamp('2022-06-18 01:00:00'),
#  Timestamp('2022-06-18 02:00:00'),
#  Timestamp('2022-06-18 03:00:00'),
#  Timestamp('2022-06-18 04:00:00'),
#  Timestamp('2022-06-18 05:00:00'),
#  Timestamp('2022-06-18 06:00:00'),
#  Timestamp('2022-06-18 07:00:00'),
#  Timestamp('2022-06-18 08:00:00'),
#  Timestamp('2022-06-18 09:00:00'),
#  Timestamp('2022-06-18 10:00:00'),
#  Timestamp('2022-06-18 11:00:00'),
#  Timestamp('2022-06-18 12:00:00'),
#  Timestamp('2022-06-18 13:00:00'),
#  Timestamp('2022-06-18 14:00:00'),
#  Timestamp('2022-06-18 15:00:00'),
#  Timestamp('2022-06-18 16:00:00'),
#  Timestamp('2022-06-18 17:00:00'),
#  Timestamp('2022-06-18 18:00:00'),
#  Timestamp('2022-06-18 19:00:00'),
#  Timestamp('2022-06-18 20:00:00'),
#  Timestamp('2022-06-18 21:00:00'),
#  Timestamp('2022-06-18 22:00:00'),
#  Timestamp('2022-06-18 23:00:00'),
#  Timestamp('2022-06-19 00:00:00'),
#  Timestamp('2022-06-19 01:00:00'),
#  Timestamp('2022-06-19 02:00:00'),
#  Timestamp('2022-06-19 03:00:00'),
#  Timestamp('2022-06-19 04:00:00'),
#  Timestamp('2022-06-19 05:00:00'),
#  Timestamp('2022-06-19 06:00:00'),
#  Timestamp('2022-06-19 07:00:00'),
#  Timestamp('2022-06-19 08:00:00'),
#  Timestamp('2022-06-19 09:00:00'),
#  Timestamp('2022-06-19 10:00:00'),
#  Timestamp('2022-06-19 11:00:00'),
#  Timestamp('2022-06-19 12:00:00'),
#  Timestamp('2022-06-19 13:00:00'),
#  Timestamp('2022-06-19 14:00:00'),
#  Timestamp('2022-06-19 15:00:00'),
#  Timestamp('2022-06-19 16:00:00'),
#  Timestamp('2022-06-19 17:00:00'),
#  Timestamp('2022-06-19 18:00:00'),
#  Timestamp('2022-06-19 19:00:00'),
#  Timestamp('2022-06-19 20:00:00'),
#  Timestamp('2022-06-19 21:00:00'),
#  Timestamp('2022-06-19 22:00:00'),
#  Timestamp('2022-06-19 23:00:00'),
#  Timestamp('2022-06-20 00:00:00'),
#  Timestamp('2022-06-20 01:00:00'),
#  Timestamp('2022-06-20 02:00:00'),
#  Timestamp('2022-06-20 03:00:00'),
#  Timestamp('2022-06-20 04:00:00'),
#  Timestamp('2022-06-20 05:00:00'),
#  Timestamp('2022-06-20 06:00:00'),
#  Timestamp('2022-06-20 07:00:00'),
#  Timestamp('2022-06-20 08:00:00'),
#  Timestamp('2022-06-20 09:00:00'),
#  Timestamp('2022-06-20 10:00:00'),
#  Timestamp('2022-06-20 11:00:00'),
#  Timestamp('2022-06-20 12:00:00'),
#  Timestamp('2022-06-20 13:00:00'),
#  Timestamp('2022-06-20 14:00:00'),
#  Timestamp('2022-06-20 15:00:00'),
#  Timestamp('2022-06-20 16:00:00'),
#  Timestamp('2022-06-20 17:00:00'),
#  Timestamp('2022-06-20 18:00:00'),
#  Timestamp('2022-06-20 19:00:00'),
#  Timestamp('2022-06-20 20:00:00'),
#  Timestamp('2022-06-20 21:00:00'),
#  Timestamp('2022-06-20 22:00:00'),
#  Timestamp('2022-06-20 23:00:00'),
#  Timestamp('2022-06-21 00:00:00'),
#  Timestamp('2022-06-21 01:00:00'),
#  Timestamp('2022-06-21 02:00:00'),
#  Timestamp('2022-06-21 03:00:00'),
#  Timestamp('2022-06-21 04:00:00'),
#  Timestamp('2022-06-21 05:00:00'),
#  Timestamp('2022-06-21 06:00:00'),
#  Timestamp('2022-06-21 07:00:00'),
#  Timestamp('2022-06-21 08:00:00'),
#  Timestamp('2022-06-21 09:00:00'),
#  Timestamp('2022-06-21 10:00:00'),
#  Timestamp('2022-06-21 11:00:00'),
#  Timestamp('2022-06-21 12:00:00'),
#  Timestamp('2022-06-21 13:00:00'),
#  Timestamp('2022-06-21 14:00:00'),
#  Timestamp('2022-06-21 15:00:00'),
#  Timestamp('2022-06-21 16:00:00'),
#  Timestamp('2022-06-21 17:00:00'),
#  Timestamp('2022-06-21 18:00:00'),
#  Timestamp('2022-06-21 19:00:00'),
#  Timestamp('2022-06-21 20:00:00'),
#  Timestamp('2022-06-21 21:00:00'),
#  Timestamp('2022-06-21 22:00:00'),
#  Timestamp('2022-06-21 23:00:00'),
#  Timestamp('2022-06-22 00:00:00'),
#  Timestamp('2022-06-22 01:00:00'),
#  Timestamp('2022-06-22 02:00:00'),
#  Timestamp('2022-06-22 03:00:00'),
#  Timestamp('2022-06-22 04:00:00'),
#  Timestamp('2022-06-22 05:00:00'),
#  Timestamp('2022-06-22 06:00:00'),
#  Timestamp('2022-06-22 07:00:00'),
#  Timestamp('2022-06-22 08:00:00'),
#  Timestamp('2022-06-22 09:00:00'),
#  Timestamp('2022-06-22 10:00:00'),
#  Timestamp('2022-06-22 11:00:00'),
#  Timestamp('2022-06-22 12:00:00'),
#  Timestamp('2022-06-22 13:00:00'),
#  Timestamp('2022-06-22 14:00:00'),
#  Timestamp('2022-06-22 15:00:00'),
#  Timestamp('2022-06-22 16:00:00'),
#  Timestamp('2022-06-22 17:00:00'),
#  Timestamp('2022-06-22 18:00:00'),
#  Timestamp('2022-06-22 19:00:00'),
#  Timestamp('2022-06-22 20:00:00'),
#  Timestamp('2022-06-22 21:00:00'),
#  Timestamp('2022-06-22 22:00:00'),
#  Timestamp('2022-06-22 23:00:00'),
#  Timestamp('2022-06-23 00:00:00'),
#  Timestamp('2022-06-23 01:00:00'),
#  Timestamp('2022-06-23 02:00:00'),
#  Timestamp('2022-06-23 03:00:00'),
#  Timestamp('2022-06-23 04:00:00'),
#  Timestamp('2022-06-23 05:00:00'),
#  Timestamp('2022-06-23 06:00:00'),
#  Timestamp('2022-06-23 07:00:00'),
#  Timestamp('2022-06-23 08:00:00'),
#  Timestamp('2022-06-23 09:00:00'),
#  Timestamp('2022-06-23 10:00:00'),
#  Timestamp('2022-06-23 11:00:00'),
#  Timestamp('2022-06-23 12:00:00'),
#  Timestamp('2022-06-23 13:00:00'),
#  Timestamp('2022-06-23 14:00:00'),
#  Timestamp('2022-06-23 15:00:00'),
#  Timestamp('2022-06-23 16:00:00'),
#  Timestamp('2022-06-23 17:00:00'),
#  Timestamp('2022-06-23 18:00:00'),
#  Timestamp('2022-06-23 19:00:00'),
#  Timestamp('2022-06-23 20:00:00'),
#  Timestamp('2022-06-23 21:00:00'),
#  Timestamp('2022-06-23 22:00:00'),
#  Timestamp('2022-06-23 23:00:00'),
#  Timestamp('2022-06-24 00:00:00'),
#  Timestamp('2022-06-24 01:00:00'),
#  Timestamp('2022-06-24 02:00:00'),
#  Timestamp('2022-06-24 03:00:00'),
#  Timestamp('2022-06-24 04:00:00'),
#  Timestamp('2022-06-24 05:00:00'),
#  Timestamp('2022-06-24 06:00:00'),
#  Timestamp('2022-06-24 07:00:00'),
#  Timestamp('2022-06-24 08:00:00'),
#  Timestamp('2022-06-24 09:00:00'),
#  Timestamp('2022-06-24 10:00:00'),
#  Timestamp('2022-06-24 11:00:00'),
#  Timestamp('2022-06-24 12:00:00'),
#  Timestamp('2022-06-24 13:00:00'),
#  Timestamp('2022-06-24 14:00:00'),
#  Timestamp('2022-06-24 15:00:00'),
#  Timestamp('2022-06-24 16:00:00'),
#  Timestamp('2022-06-24 17:00:00'),
#  Timestamp('2022-06-24 18:00:00'),
#  Timestamp('2022-06-24 19:00:00'),
#  Timestamp('2022-06-24 20:00:00'),
#  Timestamp('2022-06-24 21:00:00'),
#  Timestamp('2022-06-24 22:00:00'),
#  Timestamp('2022-06-24 23:00:00'),
#  Timestamp('2022-06-25 00:00:00'),
#  Timestamp('2022-06-25 01:00:00'),
#  Timestamp('2022-06-25 02:00:00'),
#  Timestamp('2022-06-25 03:00:00'),
#  Timestamp('2022-06-25 04:00:00'),
#  Timestamp('2022-06-25 05:00:00'),
#  Timestamp('2022-06-25 06:00:00'),
#  Timestamp('2022-06-25 07:00:00'),
#  Timestamp('2022-06-25 08:00:00'),
#  Timestamp('2022-06-25 09:00:00'),
#  Timestamp('2022-06-25 10:00:00'),
#  Timestamp('2022-06-25 11:00:00'),
#  Timestamp('2022-06-25 12:00:00'),
#  Timestamp('2022-06-25 13:00:00'),
#  Timestamp('2022-06-25 14:00:00'),
#  Timestamp('2022-06-25 15:00:00'),
#  Timestamp('2022-06-25 16:00:00'),
#  Timestamp('2022-06-25 17:00:00'),
#  Timestamp('2022-06-25 18:00:00'),
#  Timestamp('2022-06-25 19:00:00'),
#  Timestamp('2022-06-25 20:00:00'),
#  Timestamp('2022-06-25 21:00:00'),
#  Timestamp('2022-06-25 22:00:00'),
#  Timestamp('2022-06-25 23:00:00'),
#  Timestamp('2022-06-26 00:00:00'),
#  Timestamp('2022-06-26 01:00:00'),
#  Timestamp('2022-06-26 02:00:00'),
#  Timestamp('2022-06-26 03:00:00'),
#  Timestamp('2022-06-26 04:00:00'),
#  Timestamp('2022-06-26 05:00:00'),
#  Timestamp('2022-06-26 06:00:00'),
#  Timestamp('2022-06-26 07:00:00'),
#  Timestamp('2022-06-26 08:00:00'),
#  Timestamp('2022-06-26 09:00:00'),
#  Timestamp('2022-06-26 10:00:00'),
#  Timestamp('2022-06-26 11:00:00'),
#  Timestamp('2022-06-26 12:00:00'),
#  Timestamp('2022-06-26 13:00:00'),
#  Timestamp('2022-06-26 14:00:00'),
#  Timestamp('2022-06-26 15:00:00'),
#  Timestamp('2022-06-26 16:00:00'),
#  Timestamp('2022-06-26 17:00:00'),
#  Timestamp('2022-06-26 18:00:00'),
#  Timestamp('2022-06-26 19:00:00'),
#  Timestamp('2022-06-26 20:00:00'),
#  Timestamp('2022-06-26 21:00:00'),
#  Timestamp('2022-06-26 22:00:00'),
#  Timestamp('2022-06-26 23:00:00'),
#  Timestamp('2022-06-27 00:00:00'),
#  Timestamp('2022-06-27 01:00:00'),
#  Timestamp('2022-06-27 02:00:00'),
#  Timestamp('2022-06-27 03:00:00'),
#  Timestamp('2022-06-27 04:00:00'),
#  Timestamp('2022-06-27 05:00:00'),
#  Timestamp('2022-06-27 06:00:00'),
#  Timestamp('2022-06-27 07:00:00'),
#  Timestamp('2022-06-27 08:00:00'),
#  Timestamp('2022-06-27 09:00:00'),
#  Timestamp('2022-06-27 10:00:00'),
#  Timestamp('2022-06-27 11:00:00'),
#  Timestamp('2022-06-27 12:00:00'),
#  Timestamp('2022-06-27 13:00:00'),
#  Timestamp('2022-06-27 14:00:00'),
#  Timestamp('2022-06-27 15:00:00'),
#  Timestamp('2022-06-27 16:00:00'),
#  Timestamp('2022-06-27 17:00:00'),
#  Timestamp('2022-06-27 18:00:00'),
#  Timestamp('2022-06-27 19:00:00'),
#  Timestamp('2022-06-27 20:00:00'),
#  Timestamp('2022-06-27 21:00:00'),
#  Timestamp('2022-06-27 22:00:00'),
#  Timestamp('2022-06-27 23:00:00'),
#  Timestamp('2022-06-28 00:00:00'),
#  Timestamp('2022-06-28 01:00:00'),
#  Timestamp('2022-06-28 02:00:00'),
#  Timestamp('2022-06-28 03:00:00'),
#  Timestamp('2022-06-28 04:00:00'),
#  Timestamp('2022-06-28 05:00:00'),
#  Timestamp('2022-06-28 06:00:00'),
#  Timestamp('2022-06-28 07:00:00'),
#  Timestamp('2022-06-28 08:00:00'),
#  Timestamp('2022-06-28 09:00:00'),
#  Timestamp('2022-06-28 10:00:00'),
#  Timestamp('2022-06-28 11:00:00'),
#  Timestamp('2022-06-28 12:00:00'),
#  Timestamp('2022-06-28 13:00:00'),
#  Timestamp('2022-06-28 14:00:00'),
#  Timestamp('2022-06-28 15:00:00'),
#  Timestamp('2022-06-28 16:00:00'),
#  Timestamp('2022-06-28 17:00:00'),
#  Timestamp('2022-06-28 18:00:00'),
#  Timestamp('2022-06-28 19:00:00'),
#  Timestamp('2022-06-28 20:00:00'),
#  Timestamp('2022-06-28 21:00:00'),
#  Timestamp('2022-06-28 22:00:00'),
#  Timestamp('2022-06-28 23:00:00'),
#  Timestamp('2022-06-29 00:00:00'),
#  Timestamp('2022-06-29 01:00:00'),
#  Timestamp('2022-06-29 02:00:00'),
#  Timestamp('2022-06-29 03:00:00'),
#  Timestamp('2022-06-29 04:00:00'),
#  Timestamp('2022-06-29 05:00:00'),
#  Timestamp('2022-06-29 06:00:00'),
#  Timestamp('2022-06-29 07:00:00'),
#  Timestamp('2022-06-29 08:00:00'),
#  Timestamp('2022-06-29 09:00:00'),
#  Timestamp('2022-06-29 10:00:00'),
#  Timestamp('2022-06-29 11:00:00'),
#  Timestamp('2022-06-29 12:00:00'),
#  Timestamp('2022-06-29 13:00:00'),
#  Timestamp('2022-06-29 14:00:00'),
#  Timestamp('2022-06-29 15:00:00'),
#  Timestamp('2022-06-29 16:00:00'),
#  Timestamp('2022-06-29 17:00:00'),
#  Timestamp('2022-06-29 18:00:00'),
#  Timestamp('2022-06-29 19:00:00'),
#  Timestamp('2022-06-29 20:00:00'),
#  Timestamp('2022-06-29 21:00:00'),
#  Timestamp('2022-06-29 22:00:00'),
#  Timestamp('2022-06-29 23:00:00'),
#  Timestamp('2022-06-30 00:00:00'),
#  Timestamp('2022-06-30 01:00:00'),
#  Timestamp('2022-06-30 02:00:00'),
#  Timestamp('2022-06-30 03:00:00'),
#  Timestamp('2022-06-30 04:00:00'),
#  Timestamp('2022-06-30 05:00:00'),
#  Timestamp('2022-06-30 06:00:00'),
#  Timestamp('2022-06-30 07:00:00'),
#  Timestamp('2022-06-30 08:00:00'),
#  Timestamp('2022-06-30 09:00:00'),
#  Timestamp('2022-06-30 10:00:00'),
#  Timestamp('2022-06-30 11:00:00'),
#  Timestamp('2022-06-30 12:00:00'),
#  Timestamp('2022-06-30 13:00:00'),
#  Timestamp('2022-06-30 14:00:00'),
#  Timestamp('2022-06-30 15:00:00'),
#  Timestamp('2022-06-30 16:00:00'),
#  Timestamp('2022-06-30 17:00:00'),
#  Timestamp('2022-06-30 18:00:00'),
#  Timestamp('2022-06-30 19:00:00'),
#  Timestamp('2022-06-30 20:00:00'),
#  Timestamp('2022-06-30 21:00:00'),
#  Timestamp('2022-06-30 22:00:00'),
#  Timestamp('2022-06-30 23:00:00'),
#  Timestamp('2022-07-01 00:00:00'),
#  Timestamp('2022-07-01 01:00:00'),
#  Timestamp('2022-07-01 02:00:00'),
#  Timestamp('2023-03-01 00:00:00'),
#  Timestamp('2023-03-01 01:00:00'),
#  Timestamp('2023-03-01 02:00:00'),
#  Timestamp('2023-11-12 00:00:00'),
#  Timestamp('2023-11-12 01:00:00'),
#  Timestamp('2023-11-12 02:00:00'),
#  Timestamp('2023-11-12 03:00:00'),
#  Timestamp('2023-11-12 04:00:00'),
#  Timestamp('2023-11-12 05:00:00'),
#  Timestamp('2023-11-12 06:00:00'),
#  Timestamp('2023-11-12 07:00:00'),
#  Timestamp('2023-11-12 08:00:00'),
#  Timestamp('2024-01-03 00:00:00'),
#  Timestamp('2024-01-03 01:00:00'),
#  Timestamp('2024-01-03 02:00:00'),
#  Timestamp('2024-01-03 03:00:00'),
#  Timestamp('2024-01-03 04:00:00'),
#  Timestamp('2024-01-03 05:00:00'),
#  Timestamp('2024-01-03 06:00:00'),
#  Timestamp('2024-01-03 07:00:00'),
#  Timestamp('2024-01-03 08:00:00')}

# %% [markdown]
# ## We must account for these missing hours.

# %% [markdown]
# ### Import all calls made during IDX conversion. Determine holes in those calls and, again, confirm the holes really are because of missing data.

# %% [markdown]
# Latest `idx_calls.pkl` is created in latest `conversion` version.

# %%
with open("idx_calls.pkl", "rb") as input_file:
    idx_calls = pickle.load(input_file)

print(f'total hours called during idx conversion is {len(idx_calls)}')
# Out:
# total hours called during idx conversion is 25053

# %% [markdown]
# #### Ensure that all the missing_tflags were not called during IDX conversion in the first place.

# %%
idx_calls_set = set()

for call in idx_calls:
    idx_calls_set.add(pd.Timestamp(call[2]))

desired_not_called = desired_tflag_set.difference(idx_calls_set)

print(f'len(idx_calls_set) = {len(idx_calls_set)}')
print(f'len(desired_not_called.difference(missing_tflags)) = {len(desired_not_called.difference(missing_tflags))}')
# Out:
# len(idx_calls_set) = 25053
# len(desired_not_called.difference(missing_tflags)) = 0

# %% [markdown]
# #### Good, now let's see if the missing_tflags aren't available from firesmoke.ca...
# For each missing date, let's just grab that day and the 4 that **precede** it, at each dataset. Then we'll check if any of those downloaded files have the missing hours available in them...
#
# We may have somehow failed to download all available netCDF files in `data_download` workflow...

# %%
# directory to hold the downloaded files
garbage = '/usr/sci/scratch_nvme/arleth/total_garbage'

# %% [markdown]
# From all the failed hours, get the DDMMYYYY dates, this is what we use to query firesmoke.ca

# %%
missing_dates = set()

for t in missing_tflags:
    missing_dates.add(t.normalize())

missing_dates
# Out:
# {Timestamp('2021-03-03 00:00:00'),
#  Timestamp('2022-02-16 00:00:00'),
#  Timestamp('2022-06-02 00:00:00'),
#  Timestamp('2022-06-03 00:00:00'),
#  Timestamp('2022-06-04 00:00:00'),
#  Timestamp('2022-06-05 00:00:00'),
#  Timestamp('2022-06-06 00:00:00'),
#  Timestamp('2022-06-07 00:00:00'),
#  Timestamp('2022-06-08 00:00:00'),
#  Timestamp('2022-06-09 00:00:00'),
#  Timestamp('2022-06-10 00:00:00'),
#  Timestamp('2022-06-11 00:00:00'),
#  Timestamp('2022-06-12 00:00:00'),
#  Timestamp('2022-06-13 00:00:00'),
#  Timestamp('2022-06-14 00:00:00'),
#  Timestamp('2022-06-15 00:00:00'),
#  Timestamp('2022-06-16 00:00:00'),
#  Timestamp('2022-06-17 00:00:00'),
#  Timestamp('2022-06-18 00:00:00'),
#  Timestamp('2022-06-19 00:00:00'),
#  Timestamp('2022-06-20 00:00:00'),
#  Timestamp('2022-06-21 00:00:00'),
#  Timestamp('2022-06-22 00:00:00'),
#  Timestamp('2022-06-23 00:00:00'),
#  Timestamp('2022-06-24 00:00:00'),
#  Timestamp('2022-06-25 00:00:00'),
#  Timestamp('2022-06-26 00:00:00'),
#  Timestamp('2022-06-27 00:00:00'),
#  Timestamp('2022-06-28 00:00:00'),
#  Timestamp('2022-06-29 00:00:00'),
#  Timestamp('2022-06-30 00:00:00'),
#  Timestamp('2022-07-01 00:00:00'),
#  Timestamp('2023-03-01 00:00:00'),
#  Timestamp('2023-11-12 00:00:00'),
#  Timestamp('2024-01-03 00:00:00')}

# %%
# make sequence of queries to download, using missing_tflags and dataset metadata
ids = ["BSC18CA12-01", "BSC00CA12-01", "BSC06CA12-01", "BSC12CA12-01"]
init_times = ["02", "08", "14", "20"]
to_download = set()

# for all missing dates
for date in missing_dates:
    # for 4 days
    for i in range(4):
        curr_date = date + pd.Timedelta(days=-i)
        
        # build date string for query
        date_str = curr_date.strftime('%Y%m%d')
        
        # for each dataset
        for id_, init_time in zip(ids, init_times):
            # build URL string to download from and directory & filename to download to
            url = f'https://firesmoke.ca/forecasts/{id_}/{date_str}{init_time}/dispersion.nc'
            directory = f'{garbage}/{id_}/dispersion_{date_str}.nc'
            to_download.add((url, directory))

print(f'there are {len(to_download)} files to try downloading...')
# Out:
# there are 212 files to try downloading...

# %% [markdown]
# The following code block is for downloading the files, I commented it out to avoid rerunning the download script, overwriting files.. etc.

# %%
# # download files, do this as a python script by doing `nbconvert --to script...`, 
# # it's faster somehow
# for q in tqdm(to_download):
#     print(f'downloading {q[0]} to {q[1]}')
#     wget.download(q[0], out=q[1])

# %%
to_download
# Out:
# {('https://firesmoke.ca/forecasts/BSC00CA12-01/2021022808/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20210228.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2021030108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20210301.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2021030208/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20210302.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2021030308/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20210303.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022021308/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220213.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022021408/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220214.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022021508/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220215.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022021608/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220216.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022053008/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220530.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022053108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220531.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220601.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060208/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220602.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060308/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220603.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060408/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220604.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060508/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220605.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060608/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220606.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060708/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220607.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060808/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220608.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022060908/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220609.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061008/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220610.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220611.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061208/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220612.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061308/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220613.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061408/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220614.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061508/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220615.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061608/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220616.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061708/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220617.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061808/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220618.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022061908/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220619.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062008/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220620.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220621.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062208/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220622.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062308/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220623.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062408/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220624.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062508/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220625.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062608/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220626.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062708/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220627.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062808/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220628.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022062908/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220629.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022063008/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220630.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2022070108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20220701.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023022608/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20230226.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023022708/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20230227.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023022808/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20230228.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023030108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20230301.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023110908/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20231109.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023111008/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20231110.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023111108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20231111.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023111208/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20231112.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2023123108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20231231.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2024010108/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20240101.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2024010208/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20240102.nc'),
#  ('https://firesmoke.ca/forecasts/BSC00CA12-01/2024010308/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC00CA12-01/dispersion_20240103.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2021022814/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20210228.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2021030114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20210301.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2021030214/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20210302.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2021030314/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20210303.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022021314/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220213.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022021414/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220214.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022021514/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220215.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022021614/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220216.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022053014/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220530.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022053114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220531.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220601.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060214/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220602.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060314/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220603.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060414/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220604.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060514/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220605.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060614/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220606.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060714/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220607.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060814/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220608.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022060914/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220609.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061014/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220610.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220611.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061214/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220612.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061314/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220613.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061414/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220614.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061514/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220615.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061614/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220616.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061714/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220617.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061814/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220618.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022061914/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220619.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062014/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220620.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220621.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062214/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220622.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062314/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220623.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062414/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220624.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062514/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220625.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062614/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220626.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062714/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220627.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062814/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220628.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022062914/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220629.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022063014/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220630.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2022070114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20220701.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023022614/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20230226.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023022714/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20230227.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023022814/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20230228.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023030114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20230301.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023110914/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20231109.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023111014/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20231110.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023111114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20231111.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023111214/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20231112.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2023123114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20231231.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2024010114/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20240101.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2024010214/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20240102.nc'),
#  ('https://firesmoke.ca/forecasts/BSC06CA12-01/2024010314/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC06CA12-01/dispersion_20240103.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2021022820/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20210228.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2021030120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20210301.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2021030220/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20210302.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2021030320/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20210303.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022021320/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220213.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022021420/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220214.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022021520/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220215.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022021620/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220216.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022053020/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220530.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022053120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220531.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220601.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060220/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220602.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060320/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220603.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060420/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220604.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060520/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220605.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060620/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220606.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060720/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220607.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060820/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220608.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022060920/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220609.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061020/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220610.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220611.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061220/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220612.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061320/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220613.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061420/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220614.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061520/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220615.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061620/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220616.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061720/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220617.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061820/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220618.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022061920/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220619.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062020/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220620.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220621.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062220/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220622.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062320/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220623.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062420/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220624.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062520/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220625.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062620/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220626.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062720/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220627.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062820/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220628.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022062920/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220629.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022063020/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220630.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2022070120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20220701.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023022620/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20230226.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023022720/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20230227.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023022820/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20230228.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023030120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20230301.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023110920/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20231109.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023111020/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20231110.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023111120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20231111.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023111220/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20231112.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2023123120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20231231.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2024010120/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20240101.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2024010220/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20240102.nc'),
#  ('https://firesmoke.ca/forecasts/BSC12CA12-01/2024010320/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC12CA12-01/dispersion_20240103.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2021022802/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20210228.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2021030102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20210301.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2021030202/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20210302.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2021030302/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20210303.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022021302/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220213.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022021402/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220214.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022021502/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220215.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022021602/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220216.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022053002/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220530.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022053102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220531.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220601.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060202/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220602.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060302/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220603.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060402/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220604.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060502/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220605.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060602/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220606.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060702/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220607.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060802/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220608.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022060902/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220609.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061002/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220610.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220611.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061202/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220612.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061302/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220613.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061402/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220614.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061502/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220615.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061602/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220616.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061702/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220617.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061802/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220618.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022061902/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220619.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062002/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220620.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220621.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062202/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220622.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062302/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220623.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062402/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220624.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062502/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220625.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062602/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220626.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062702/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220627.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062802/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220628.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022062902/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220629.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022063002/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220630.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2022070102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20220701.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023022602/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20230226.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023022702/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20230227.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023022802/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20230228.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023030102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20230301.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023110902/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20231109.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023111002/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20231110.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023111102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20231111.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023111202/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20231112.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2023123102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20231231.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2024010102/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20240101.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2024010202/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20240102.nc'),
#  ('https://firesmoke.ca/forecasts/BSC18CA12-01/2024010302/dispersion.nc',
#   '/usr/sci/scratch_nvme/arleth/total_garbage/BSC18CA12-01/dispersion_20240103.nc')}

# %% [markdown]
# #### See all hours available from files we downloaded. Check intersection with our missing tflags.

# %%
# Track files that successfully opened
successful_files = {id_: [] for id_ in ids}

# Set of all hours available from the files newly downloaded
new_hours = set()

# Try opening all downloaded files
for query in to_download:
    # get file path from current query from to_download
    path = query[1]
    # get file name from query
    file_name = path[-len('dispersion_20210228.nc'):]
    # get id from path string
    id_ = path[-len('BSC00CA12-01/dispersion_20210228.nc'):-len('/dispersion_20210228.nc')]

    # keep track of which files successfully open
    try:
        # open the file with xarray
        ds = xr.open_dataset(path)

        # append file name to successful_files
        successful_files[id_].append(path)
        # add each available hour to new_hours
        for h in range(ds.sizes["TSTEP"]):
            vals = ds['TFLAG'].values[h]
            curr_tflag = parse_tflag(ds['TFLAG'].values[h][0])
            panda_tflag = pd.Timestamp(curr_tflag)
            new_hours.add((id_, panda_tflag))
    except:
        # netcdf file does not exist
        print(f'FAILED, {id_}, {file_name}')
        continue
# Out:
# FAILED, BSC18CA12-01, dispersion_20230228.nc
# FAILED, BSC18CA12-01, dispersion_20231231.nc
# FAILED, BSC12CA12-01, dispersion_20240101.nc
# FAILED, BSC18CA12-01, dispersion_20240101.nc
# FAILED, BSC12CA12-01, dispersion_20220214.nc
# FAILED, BSC12CA12-01, dispersion_20220215.nc
# FAILED, BSC18CA12-01, dispersion_20231111.nc
# FAILED, BSC06CA12-01, dispersion_20240102.nc
# FAILED, BSC12CA12-01, dispersion_20231110.nc
# FAILED, BSC12CA12-01, dispersion_20231109.nc
# FAILED, BSC06CA12-01, dispersion_20240103.nc
# FAILED, BSC06CA12-01, dispersion_20231112.nc
# FAILED, BSC00CA12-01, dispersion_20230228.nc
# FAILED, BSC06CA12-01, dispersion_20220624.nc
# FAILED, BSC12CA12-01, dispersion_20240102.nc
# FAILED, BSC06CA12-01, dispersion_20231110.nc
# FAILED, BSC00CA12-01, dispersion_20220215.nc
# FAILED, BSC12CA12-01, dispersion_20240103.nc
# FAILED, BSC12CA12-01, dispersion_20230228.nc
# FAILED, BSC06CA12-01, dispersion_20231109.nc
# FAILED, BSC00CA12-01, dispersion_20231111.nc
# FAILED, BSC18CA12-01, dispersion_20240102.nc
# FAILED, BSC12CA12-01, dispersion_20231231.nc
# FAILED, BSC12CA12-01, dispersion_20220611.nc
# FAILED, BSC06CA12-01, dispersion_20231231.nc
# FAILED, BSC06CA12-01, dispersion_20230228.nc
# FAILED, BSC18CA12-01, dispersion_20240103.nc
# FAILED, BSC00CA12-01, dispersion_20240102.nc
# FAILED, BSC18CA12-01, dispersion_20210303.nc
# FAILED, BSC06CA12-01, dispersion_20220215.nc
# FAILED, BSC18CA12-01, dispersion_20231110.nc
# FAILED, BSC12CA12-01, dispersion_20231111.nc
# FAILED, BSC18CA12-01, dispersion_20220215.nc
# FAILED, BSC18CA12-01, dispersion_20220612.nc
# FAILED, BSC06CA12-01, dispersion_20231111.nc
# FAILED, BSC06CA12-01, dispersion_20240101.nc
# FAILED, BSC12CA12-01, dispersion_20230227.nc
# FAILED, BSC18CA12-01, dispersion_20231112.nc
# FAILED, BSC18CA12-01, dispersion_20231109.nc
# FAILED, BSC12CA12-01, dispersion_20231112.nc

# %%
for id_ in ids:
    print(f'For {id_}:')
    print(f'Of files downloaded, there are {len(successful_files[id_])} that open successfully.')
    print('---')
print(f'Of files downloaded, there are {len(new_hours)} hours available.')
# Out:
# For BSC18CA12-01:
# Of files downloaded, there are 41 that open successfully.
# ---
# For BSC00CA12-01:
# Of files downloaded, there are 49 that open successfully.
# ---
# For BSC06CA12-01:
# Of files downloaded, there are 42 that open successfully.
# ---
# For BSC12CA12-01:
# Of files downloaded, there are 40 that open successfully.
# ---
# Of files downloaded, there are 4932 hours available.

# %% [markdown]
# #### Determine how many new hours were downloaded that we could add to the final IDX conversion, if any...

# %%
# get all timestamps downloaded
hours_set = set()

# get each timestamp, add it to a set
for hour in new_hours:
    hours_set.add(hour[1])

print(f'there are {len(hours_set.intersection(missing_tflags))} hours available from downloaded data')
# Out:
# there are 747 hours available from downloaded data

# %%
hours_set.intersection(missing_tflags)
# Out:
# {Timestamp('2021-03-03 00:00:00'),
#  Timestamp('2021-03-03 01:00:00'),
#  Timestamp('2021-03-03 02:00:00'),
#  Timestamp('2021-03-03 03:00:00'),
#  Timestamp('2021-03-03 04:00:00'),
#  Timestamp('2021-03-03 05:00:00'),
#  Timestamp('2021-03-03 06:00:00'),
#  Timestamp('2021-03-03 07:00:00'),
#  Timestamp('2021-03-03 08:00:00'),
#  Timestamp('2021-03-03 09:00:00'),
#  Timestamp('2021-03-03 10:00:00'),
#  Timestamp('2021-03-03 11:00:00'),
#  Timestamp('2021-03-03 12:00:00'),
#  Timestamp('2021-03-03 13:00:00'),
#  Timestamp('2021-03-03 14:00:00'),
#  Timestamp('2021-03-03 15:00:00'),
#  Timestamp('2021-03-03 16:00:00'),
#  Timestamp('2021-03-03 17:00:00'),
#  Timestamp('2021-03-03 18:00:00'),
#  Timestamp('2021-03-03 19:00:00'),
#  Timestamp('2021-03-03 20:00:00'),
#  Timestamp('2021-03-03 21:00:00'),
#  Timestamp('2021-03-03 22:00:00'),
#  Timestamp('2021-03-03 23:00:00'),
#  Timestamp('2022-02-16 00:00:00'),
#  Timestamp('2022-02-16 01:00:00'),
#  Timestamp('2022-02-16 02:00:00'),
#  Timestamp('2022-06-02 00:00:00'),
#  Timestamp('2022-06-02 01:00:00'),
#  Timestamp('2022-06-02 02:00:00'),
#  Timestamp('2022-06-02 03:00:00'),
#  Timestamp('2022-06-02 04:00:00'),
#  Timestamp('2022-06-02 05:00:00'),
#  Timestamp('2022-06-02 06:00:00'),
#  Timestamp('2022-06-02 07:00:00'),
#  Timestamp('2022-06-02 08:00:00'),
#  Timestamp('2022-06-02 09:00:00'),
#  Timestamp('2022-06-02 10:00:00'),
#  Timestamp('2022-06-02 11:00:00'),
#  Timestamp('2022-06-02 12:00:00'),
#  Timestamp('2022-06-02 13:00:00'),
#  Timestamp('2022-06-02 14:00:00'),
#  Timestamp('2022-06-02 15:00:00'),
#  Timestamp('2022-06-02 16:00:00'),
#  Timestamp('2022-06-02 17:00:00'),
#  Timestamp('2022-06-02 18:00:00'),
#  Timestamp('2022-06-02 19:00:00'),
#  Timestamp('2022-06-02 20:00:00'),
#  Timestamp('2022-06-02 21:00:00'),
#  Timestamp('2022-06-02 22:00:00'),
#  Timestamp('2022-06-02 23:00:00'),
#  Timestamp('2022-06-03 00:00:00'),
#  Timestamp('2022-06-03 01:00:00'),
#  Timestamp('2022-06-03 02:00:00'),
#  Timestamp('2022-06-03 03:00:00'),
#  Timestamp('2022-06-03 04:00:00'),
#  Timestamp('2022-06-03 05:00:00'),
#  Timestamp('2022-06-03 06:00:00'),
#  Timestamp('2022-06-03 07:00:00'),
#  Timestamp('2022-06-03 08:00:00'),
#  Timestamp('2022-06-03 09:00:00'),
#  Timestamp('2022-06-03 10:00:00'),
#  Timestamp('2022-06-03 11:00:00'),
#  Timestamp('2022-06-03 12:00:00'),
#  Timestamp('2022-06-03 13:00:00'),
#  Timestamp('2022-06-03 14:00:00'),
#  Timestamp('2022-06-03 15:00:00'),
#  Timestamp('2022-06-03 16:00:00'),
#  Timestamp('2022-06-03 17:00:00'),
#  Timestamp('2022-06-03 18:00:00'),
#  Timestamp('2022-06-03 19:00:00'),
#  Timestamp('2022-06-03 20:00:00'),
#  Timestamp('2022-06-03 21:00:00'),
#  Timestamp('2022-06-03 22:00:00'),
#  Timestamp('2022-06-03 23:00:00'),
#  Timestamp('2022-06-04 00:00:00'),
#  Timestamp('2022-06-04 01:00:00'),
#  Timestamp('2022-06-04 02:00:00'),
#  Timestamp('2022-06-04 03:00:00'),
#  Timestamp('2022-06-04 04:00:00'),
#  Timestamp('2022-06-04 05:00:00'),
#  Timestamp('2022-06-04 06:00:00'),
#  Timestamp('2022-06-04 07:00:00'),
#  Timestamp('2022-06-04 08:00:00'),
#  Timestamp('2022-06-04 09:00:00'),
#  Timestamp('2022-06-04 10:00:00'),
#  Timestamp('2022-06-04 11:00:00'),
#  Timestamp('2022-06-04 12:00:00'),
#  Timestamp('2022-06-04 13:00:00'),
#  Timestamp('2022-06-04 14:00:00'),
#  Timestamp('2022-06-04 15:00:00'),
#  Timestamp('2022-06-04 16:00:00'),
#  Timestamp('2022-06-04 17:00:00'),
#  Timestamp('2022-06-04 18:00:00'),
#  Timestamp('2022-06-04 19:00:00'),
#  Timestamp('2022-06-04 20:00:00'),
#  Timestamp('2022-06-04 21:00:00'),
#  Timestamp('2022-06-04 22:00:00'),
#  Timestamp('2022-06-04 23:00:00'),
#  Timestamp('2022-06-05 00:00:00'),
#  Timestamp('2022-06-05 01:00:00'),
#  Timestamp('2022-06-05 02:00:00'),
#  Timestamp('2022-06-05 03:00:00'),
#  Timestamp('2022-06-05 04:00:00'),
#  Timestamp('2022-06-05 05:00:00'),
#  Timestamp('2022-06-05 06:00:00'),
#  Timestamp('2022-06-05 07:00:00'),
#  Timestamp('2022-06-05 08:00:00'),
#  Timestamp('2022-06-05 09:00:00'),
#  Timestamp('2022-06-05 10:00:00'),
#  Timestamp('2022-06-05 11:00:00'),
#  Timestamp('2022-06-05 12:00:00'),
#  Timestamp('2022-06-05 13:00:00'),
#  Timestamp('2022-06-05 14:00:00'),
#  Timestamp('2022-06-05 15:00:00'),
#  Timestamp('2022-06-05 16:00:00'),
#  Timestamp('2022-06-05 17:00:00'),
#  Timestamp('2022-06-05 18:00:00'),
#  Timestamp('2022-06-05 19:00:00'),
#  Timestamp('2022-06-05 20:00:00'),
#  Timestamp('2022-06-05 21:00:00'),
#  Timestamp('2022-06-05 22:00:00'),
#  Timestamp('2022-06-05 23:00:00'),
#  Timestamp('2022-06-06 00:00:00'),
#  Timestamp('2022-06-06 01:00:00'),
#  Timestamp('2022-06-06 02:00:00'),
#  Timestamp('2022-06-06 03:00:00'),
#  Timestamp('2022-06-06 04:00:00'),
#  Timestamp('2022-06-06 05:00:00'),
#  Timestamp('2022-06-06 06:00:00'),
#  Timestamp('2022-06-06 07:00:00'),
#  Timestamp('2022-06-06 08:00:00'),
#  Timestamp('2022-06-06 09:00:00'),
#  Timestamp('2022-06-06 10:00:00'),
#  Timestamp('2022-06-06 11:00:00'),
#  Timestamp('2022-06-06 12:00:00'),
#  Timestamp('2022-06-06 13:00:00'),
#  Timestamp('2022-06-06 14:00:00'),
#  Timestamp('2022-06-06 15:00:00'),
#  Timestamp('2022-06-06 16:00:00'),
#  Timestamp('2022-06-06 17:00:00'),
#  Timestamp('2022-06-06 18:00:00'),
#  Timestamp('2022-06-06 19:00:00'),
#  Timestamp('2022-06-06 20:00:00'),
#  Timestamp('2022-06-06 21:00:00'),
#  Timestamp('2022-06-06 22:00:00'),
#  Timestamp('2022-06-06 23:00:00'),
#  Timestamp('2022-06-07 00:00:00'),
#  Timestamp('2022-06-07 01:00:00'),
#  Timestamp('2022-06-07 02:00:00'),
#  Timestamp('2022-06-07 03:00:00'),
#  Timestamp('2022-06-07 04:00:00'),
#  Timestamp('2022-06-07 05:00:00'),
#  Timestamp('2022-06-07 06:00:00'),
#  Timestamp('2022-06-07 07:00:00'),
#  Timestamp('2022-06-07 08:00:00'),
#  Timestamp('2022-06-07 09:00:00'),
#  Timestamp('2022-06-07 10:00:00'),
#  Timestamp('2022-06-07 11:00:00'),
#  Timestamp('2022-06-07 12:00:00'),
#  Timestamp('2022-06-07 13:00:00'),
#  Timestamp('2022-06-07 14:00:00'),
#  Timestamp('2022-06-07 15:00:00'),
#  Timestamp('2022-06-07 16:00:00'),
#  Timestamp('2022-06-07 17:00:00'),
#  Timestamp('2022-06-07 18:00:00'),
#  Timestamp('2022-06-07 19:00:00'),
#  Timestamp('2022-06-07 20:00:00'),
#  Timestamp('2022-06-07 21:00:00'),
#  Timestamp('2022-06-07 22:00:00'),
#  Timestamp('2022-06-07 23:00:00'),
#  Timestamp('2022-06-08 00:00:00'),
#  Timestamp('2022-06-08 01:00:00'),
#  Timestamp('2022-06-08 02:00:00'),
#  Timestamp('2022-06-08 03:00:00'),
#  Timestamp('2022-06-08 04:00:00'),
#  Timestamp('2022-06-08 05:00:00'),
#  Timestamp('2022-06-08 06:00:00'),
#  Timestamp('2022-06-08 07:00:00'),
#  Timestamp('2022-06-08 08:00:00'),
#  Timestamp('2022-06-08 09:00:00'),
#  Timestamp('2022-06-08 10:00:00'),
#  Timestamp('2022-06-08 11:00:00'),
#  Timestamp('2022-06-08 12:00:00'),
#  Timestamp('2022-06-08 13:00:00'),
#  Timestamp('2022-06-08 14:00:00'),
#  Timestamp('2022-06-08 15:00:00'),
#  Timestamp('2022-06-08 16:00:00'),
#  Timestamp('2022-06-08 17:00:00'),
#  Timestamp('2022-06-08 18:00:00'),
#  Timestamp('2022-06-08 19:00:00'),
#  Timestamp('2022-06-08 20:00:00'),
#  Timestamp('2022-06-08 21:00:00'),
#  Timestamp('2022-06-08 22:00:00'),
#  Timestamp('2022-06-08 23:00:00'),
#  Timestamp('2022-06-09 00:00:00'),
#  Timestamp('2022-06-09 01:00:00'),
#  Timestamp('2022-06-09 02:00:00'),
#  Timestamp('2022-06-09 03:00:00'),
#  Timestamp('2022-06-09 04:00:00'),
#  Timestamp('2022-06-09 05:00:00'),
#  Timestamp('2022-06-09 06:00:00'),
#  Timestamp('2022-06-09 07:00:00'),
#  Timestamp('2022-06-09 08:00:00'),
#  Timestamp('2022-06-09 09:00:00'),
#  Timestamp('2022-06-09 10:00:00'),
#  Timestamp('2022-06-09 11:00:00'),
#  Timestamp('2022-06-09 12:00:00'),
#  Timestamp('2022-06-09 13:00:00'),
#  Timestamp('2022-06-09 14:00:00'),
#  Timestamp('2022-06-09 15:00:00'),
#  Timestamp('2022-06-09 16:00:00'),
#  Timestamp('2022-06-09 17:00:00'),
#  Timestamp('2022-06-09 18:00:00'),
#  Timestamp('2022-06-09 19:00:00'),
#  Timestamp('2022-06-09 20:00:00'),
#  Timestamp('2022-06-09 21:00:00'),
#  Timestamp('2022-06-09 22:00:00'),
#  Timestamp('2022-06-09 23:00:00'),
#  Timestamp('2022-06-10 00:00:00'),
#  Timestamp('2022-06-10 01:00:00'),
#  Timestamp('2022-06-10 02:00:00'),
#  Timestamp('2022-06-10 03:00:00'),
#  Timestamp('2022-06-10 04:00:00'),
#  Timestamp('2022-06-10 05:00:00'),
#  Timestamp('2022-06-10 06:00:00'),
#  Timestamp('2022-06-10 07:00:00'),
#  Timestamp('2022-06-10 08:00:00'),
#  Timestamp('2022-06-10 09:00:00'),
#  Timestamp('2022-06-10 10:00:00'),
#  Timestamp('2022-06-10 11:00:00'),
#  Timestamp('2022-06-10 12:00:00'),
#  Timestamp('2022-06-10 13:00:00'),
#  Timestamp('2022-06-10 14:00:00'),
#  Timestamp('2022-06-10 15:00:00'),
#  Timestamp('2022-06-10 16:00:00'),
#  Timestamp('2022-06-10 17:00:00'),
#  Timestamp('2022-06-10 18:00:00'),
#  Timestamp('2022-06-10 19:00:00'),
#  Timestamp('2022-06-10 20:00:00'),
#  Timestamp('2022-06-10 21:00:00'),
#  Timestamp('2022-06-10 22:00:00'),
#  Timestamp('2022-06-10 23:00:00'),
#  Timestamp('2022-06-11 00:00:00'),
#  Timestamp('2022-06-11 01:00:00'),
#  Timestamp('2022-06-11 02:00:00'),
#  Timestamp('2022-06-11 03:00:00'),
#  Timestamp('2022-06-11 04:00:00'),
#  Timestamp('2022-06-11 05:00:00'),
#  Timestamp('2022-06-11 06:00:00'),
#  Timestamp('2022-06-11 07:00:00'),
#  Timestamp('2022-06-11 08:00:00'),
#  Timestamp('2022-06-11 09:00:00'),
#  Timestamp('2022-06-11 10:00:00'),
#  Timestamp('2022-06-11 11:00:00'),
#  Timestamp('2022-06-11 12:00:00'),
#  Timestamp('2022-06-11 13:00:00'),
#  Timestamp('2022-06-11 14:00:00'),
#  Timestamp('2022-06-11 15:00:00'),
#  Timestamp('2022-06-11 16:00:00'),
#  Timestamp('2022-06-11 17:00:00'),
#  Timestamp('2022-06-11 18:00:00'),
#  Timestamp('2022-06-11 19:00:00'),
#  Timestamp('2022-06-11 20:00:00'),
#  Timestamp('2022-06-11 21:00:00'),
#  Timestamp('2022-06-11 22:00:00'),
#  Timestamp('2022-06-11 23:00:00'),
#  Timestamp('2022-06-12 00:00:00'),
#  Timestamp('2022-06-12 01:00:00'),
#  Timestamp('2022-06-12 02:00:00'),
#  Timestamp('2022-06-12 03:00:00'),
#  Timestamp('2022-06-12 04:00:00'),
#  Timestamp('2022-06-12 05:00:00'),
#  Timestamp('2022-06-12 06:00:00'),
#  Timestamp('2022-06-12 07:00:00'),
#  Timestamp('2022-06-12 08:00:00'),
#  Timestamp('2022-06-12 09:00:00'),
#  Timestamp('2022-06-12 10:00:00'),
#  Timestamp('2022-06-12 11:00:00'),
#  Timestamp('2022-06-12 12:00:00'),
#  Timestamp('2022-06-12 13:00:00'),
#  Timestamp('2022-06-12 14:00:00'),
#  Timestamp('2022-06-12 15:00:00'),
#  Timestamp('2022-06-12 16:00:00'),
#  Timestamp('2022-06-12 17:00:00'),
#  Timestamp('2022-06-12 18:00:00'),
#  Timestamp('2022-06-12 19:00:00'),
#  Timestamp('2022-06-12 20:00:00'),
#  Timestamp('2022-06-12 21:00:00'),
#  Timestamp('2022-06-12 22:00:00'),
#  Timestamp('2022-06-12 23:00:00'),
#  Timestamp('2022-06-13 00:00:00'),
#  Timestamp('2022-06-13 01:00:00'),
#  Timestamp('2022-06-13 02:00:00'),
#  Timestamp('2022-06-13 03:00:00'),
#  Timestamp('2022-06-13 04:00:00'),
#  Timestamp('2022-06-13 05:00:00'),
#  Timestamp('2022-06-13 06:00:00'),
#  Timestamp('2022-06-13 07:00:00'),
#  Timestamp('2022-06-13 08:00:00'),
#  Timestamp('2022-06-13 09:00:00'),
#  Timestamp('2022-06-13 10:00:00'),
#  Timestamp('2022-06-13 11:00:00'),
#  Timestamp('2022-06-13 12:00:00'),
#  Timestamp('2022-06-13 13:00:00'),
#  Timestamp('2022-06-13 14:00:00'),
#  Timestamp('2022-06-13 15:00:00'),
#  Timestamp('2022-06-13 16:00:00'),
#  Timestamp('2022-06-13 17:00:00'),
#  Timestamp('2022-06-13 18:00:00'),
#  Timestamp('2022-06-13 19:00:00'),
#  Timestamp('2022-06-13 20:00:00'),
#  Timestamp('2022-06-13 21:00:00'),
#  Timestamp('2022-06-13 22:00:00'),
#  Timestamp('2022-06-13 23:00:00'),
#  Timestamp('2022-06-14 00:00:00'),
#  Timestamp('2022-06-14 01:00:00'),
#  Timestamp('2022-06-14 02:00:00'),
#  Timestamp('2022-06-14 03:00:00'),
#  Timestamp('2022-06-14 04:00:00'),
#  Timestamp('2022-06-14 05:00:00'),
#  Timestamp('2022-06-14 06:00:00'),
#  Timestamp('2022-06-14 07:00:00'),
#  Timestamp('2022-06-14 08:00:00'),
#  Timestamp('2022-06-14 09:00:00'),
#  Timestamp('2022-06-14 10:00:00'),
#  Timestamp('2022-06-14 11:00:00'),
#  Timestamp('2022-06-14 12:00:00'),
#  Timestamp('2022-06-14 13:00:00'),
#  Timestamp('2022-06-14 14:00:00'),
#  Timestamp('2022-06-14 15:00:00'),
#  Timestamp('2022-06-14 16:00:00'),
#  Timestamp('2022-06-14 17:00:00'),
#  Timestamp('2022-06-14 18:00:00'),
#  Timestamp('2022-06-14 19:00:00'),
#  Timestamp('2022-06-14 20:00:00'),
#  Timestamp('2022-06-14 21:00:00'),
#  Timestamp('2022-06-14 22:00:00'),
#  Timestamp('2022-06-14 23:00:00'),
#  Timestamp('2022-06-15 00:00:00'),
#  Timestamp('2022-06-15 01:00:00'),
#  Timestamp('2022-06-15 02:00:00'),
#  Timestamp('2022-06-15 03:00:00'),
#  Timestamp('2022-06-15 04:00:00'),
#  Timestamp('2022-06-15 05:00:00'),
#  Timestamp('2022-06-15 06:00:00'),
#  Timestamp('2022-06-15 07:00:00'),
#  Timestamp('2022-06-15 08:00:00'),
#  Timestamp('2022-06-15 09:00:00'),
#  Timestamp('2022-06-15 10:00:00'),
#  Timestamp('2022-06-15 11:00:00'),
#  Timestamp('2022-06-15 12:00:00'),
#  Timestamp('2022-06-15 13:00:00'),
#  Timestamp('2022-06-15 14:00:00'),
#  Timestamp('2022-06-15 15:00:00'),
#  Timestamp('2022-06-15 16:00:00'),
#  Timestamp('2022-06-15 17:00:00'),
#  Timestamp('2022-06-15 18:00:00'),
#  Timestamp('2022-06-15 19:00:00'),
#  Timestamp('2022-06-15 20:00:00'),
#  Timestamp('2022-06-15 21:00:00'),
#  Timestamp('2022-06-15 22:00:00'),
#  Timestamp('2022-06-15 23:00:00'),
#  Timestamp('2022-06-16 00:00:00'),
#  Timestamp('2022-06-16 01:00:00'),
#  Timestamp('2022-06-16 02:00:00'),
#  Timestamp('2022-06-16 03:00:00'),
#  Timestamp('2022-06-16 04:00:00'),
#  Timestamp('2022-06-16 05:00:00'),
#  Timestamp('2022-06-16 06:00:00'),
#  Timestamp('2022-06-16 07:00:00'),
#  Timestamp('2022-06-16 08:00:00'),
#  Timestamp('2022-06-16 09:00:00'),
#  Timestamp('2022-06-16 10:00:00'),
#  Timestamp('2022-06-16 11:00:00'),
#  Timestamp('2022-06-16 12:00:00'),
#  Timestamp('2022-06-16 13:00:00'),
#  Timestamp('2022-06-16 14:00:00'),
#  Timestamp('2022-06-16 15:00:00'),
#  Timestamp('2022-06-16 16:00:00'),
#  Timestamp('2022-06-16 17:00:00'),
#  Timestamp('2022-06-16 18:00:00'),
#  Timestamp('2022-06-16 19:00:00'),
#  Timestamp('2022-06-16 20:00:00'),
#  Timestamp('2022-06-16 21:00:00'),
#  Timestamp('2022-06-16 22:00:00'),
#  Timestamp('2022-06-16 23:00:00'),
#  Timestamp('2022-06-17 00:00:00'),
#  Timestamp('2022-06-17 01:00:00'),
#  Timestamp('2022-06-17 02:00:00'),
#  Timestamp('2022-06-17 03:00:00'),
#  Timestamp('2022-06-17 04:00:00'),
#  Timestamp('2022-06-17 05:00:00'),
#  Timestamp('2022-06-17 06:00:00'),
#  Timestamp('2022-06-17 07:00:00'),
#  Timestamp('2022-06-17 08:00:00'),
#  Timestamp('2022-06-17 09:00:00'),
#  Timestamp('2022-06-17 10:00:00'),
#  Timestamp('2022-06-17 11:00:00'),
#  Timestamp('2022-06-17 12:00:00'),
#  Timestamp('2022-06-17 13:00:00'),
#  Timestamp('2022-06-17 14:00:00'),
#  Timestamp('2022-06-17 15:00:00'),
#  Timestamp('2022-06-17 16:00:00'),
#  Timestamp('2022-06-17 17:00:00'),
#  Timestamp('2022-06-17 18:00:00'),
#  Timestamp('2022-06-17 19:00:00'),
#  Timestamp('2022-06-17 20:00:00'),
#  Timestamp('2022-06-17 21:00:00'),
#  Timestamp('2022-06-17 22:00:00'),
#  Timestamp('2022-06-17 23:00:00'),
#  Timestamp('2022-06-18 00:00:00'),
#  Timestamp('2022-06-18 01:00:00'),
#  Timestamp('2022-06-18 02:00:00'),
#  Timestamp('2022-06-18 03:00:00'),
#  Timestamp('2022-06-18 04:00:00'),
#  Timestamp('2022-06-18 05:00:00'),
#  Timestamp('2022-06-18 06:00:00'),
#  Timestamp('2022-06-18 07:00:00'),
#  Timestamp('2022-06-18 08:00:00'),
#  Timestamp('2022-06-18 09:00:00'),
#  Timestamp('2022-06-18 10:00:00'),
#  Timestamp('2022-06-18 11:00:00'),
#  Timestamp('2022-06-18 12:00:00'),
#  Timestamp('2022-06-18 13:00:00'),
#  Timestamp('2022-06-18 14:00:00'),
#  Timestamp('2022-06-18 15:00:00'),
#  Timestamp('2022-06-18 16:00:00'),
#  Timestamp('2022-06-18 17:00:00'),
#  Timestamp('2022-06-18 18:00:00'),
#  Timestamp('2022-06-18 19:00:00'),
#  Timestamp('2022-06-18 20:00:00'),
#  Timestamp('2022-06-18 21:00:00'),
#  Timestamp('2022-06-18 22:00:00'),
#  Timestamp('2022-06-18 23:00:00'),
#  Timestamp('2022-06-19 00:00:00'),
#  Timestamp('2022-06-19 01:00:00'),
#  Timestamp('2022-06-19 02:00:00'),
#  Timestamp('2022-06-19 03:00:00'),
#  Timestamp('2022-06-19 04:00:00'),
#  Timestamp('2022-06-19 05:00:00'),
#  Timestamp('2022-06-19 06:00:00'),
#  Timestamp('2022-06-19 07:00:00'),
#  Timestamp('2022-06-19 08:00:00'),
#  Timestamp('2022-06-19 09:00:00'),
#  Timestamp('2022-06-19 10:00:00'),
#  Timestamp('2022-06-19 11:00:00'),
#  Timestamp('2022-06-19 12:00:00'),
#  Timestamp('2022-06-19 13:00:00'),
#  Timestamp('2022-06-19 14:00:00'),
#  Timestamp('2022-06-19 15:00:00'),
#  Timestamp('2022-06-19 16:00:00'),
#  Timestamp('2022-06-19 17:00:00'),
#  Timestamp('2022-06-19 18:00:00'),
#  Timestamp('2022-06-19 19:00:00'),
#  Timestamp('2022-06-19 20:00:00'),
#  Timestamp('2022-06-19 21:00:00'),
#  Timestamp('2022-06-19 22:00:00'),
#  Timestamp('2022-06-19 23:00:00'),
#  Timestamp('2022-06-20 00:00:00'),
#  Timestamp('2022-06-20 01:00:00'),
#  Timestamp('2022-06-20 02:00:00'),
#  Timestamp('2022-06-20 03:00:00'),
#  Timestamp('2022-06-20 04:00:00'),
#  Timestamp('2022-06-20 05:00:00'),
#  Timestamp('2022-06-20 06:00:00'),
#  Timestamp('2022-06-20 07:00:00'),
#  Timestamp('2022-06-20 08:00:00'),
#  Timestamp('2022-06-20 09:00:00'),
#  Timestamp('2022-06-20 10:00:00'),
#  Timestamp('2022-06-20 11:00:00'),
#  Timestamp('2022-06-20 12:00:00'),
#  Timestamp('2022-06-20 13:00:00'),
#  Timestamp('2022-06-20 14:00:00'),
#  Timestamp('2022-06-20 15:00:00'),
#  Timestamp('2022-06-20 16:00:00'),
#  Timestamp('2022-06-20 17:00:00'),
#  Timestamp('2022-06-20 18:00:00'),
#  Timestamp('2022-06-20 19:00:00'),
#  Timestamp('2022-06-20 20:00:00'),
#  Timestamp('2022-06-20 21:00:00'),
#  Timestamp('2022-06-20 22:00:00'),
#  Timestamp('2022-06-20 23:00:00'),
#  Timestamp('2022-06-21 00:00:00'),
#  Timestamp('2022-06-21 01:00:00'),
#  Timestamp('2022-06-21 02:00:00'),
#  Timestamp('2022-06-21 03:00:00'),
#  Timestamp('2022-06-21 04:00:00'),
#  Timestamp('2022-06-21 05:00:00'),
#  Timestamp('2022-06-21 06:00:00'),
#  Timestamp('2022-06-21 07:00:00'),
#  Timestamp('2022-06-21 08:00:00'),
#  Timestamp('2022-06-21 09:00:00'),
#  Timestamp('2022-06-21 10:00:00'),
#  Timestamp('2022-06-21 11:00:00'),
#  Timestamp('2022-06-21 12:00:00'),
#  Timestamp('2022-06-21 13:00:00'),
#  Timestamp('2022-06-21 14:00:00'),
#  Timestamp('2022-06-21 15:00:00'),
#  Timestamp('2022-06-21 16:00:00'),
#  Timestamp('2022-06-21 17:00:00'),
#  Timestamp('2022-06-21 18:00:00'),
#  Timestamp('2022-06-21 19:00:00'),
#  Timestamp('2022-06-21 20:00:00'),
#  Timestamp('2022-06-21 21:00:00'),
#  Timestamp('2022-06-21 22:00:00'),
#  Timestamp('2022-06-21 23:00:00'),
#  Timestamp('2022-06-22 00:00:00'),
#  Timestamp('2022-06-22 01:00:00'),
#  Timestamp('2022-06-22 02:00:00'),
#  Timestamp('2022-06-22 03:00:00'),
#  Timestamp('2022-06-22 04:00:00'),
#  Timestamp('2022-06-22 05:00:00'),
#  Timestamp('2022-06-22 06:00:00'),
#  Timestamp('2022-06-22 07:00:00'),
#  Timestamp('2022-06-22 08:00:00'),
#  Timestamp('2022-06-22 09:00:00'),
#  Timestamp('2022-06-22 10:00:00'),
#  Timestamp('2022-06-22 11:00:00'),
#  Timestamp('2022-06-22 12:00:00'),
#  Timestamp('2022-06-22 13:00:00'),
#  Timestamp('2022-06-22 14:00:00'),
#  Timestamp('2022-06-22 15:00:00'),
#  Timestamp('2022-06-22 16:00:00'),
#  Timestamp('2022-06-22 17:00:00'),
#  Timestamp('2022-06-22 18:00:00'),
#  Timestamp('2022-06-22 19:00:00'),
#  Timestamp('2022-06-22 20:00:00'),
#  Timestamp('2022-06-22 21:00:00'),
#  Timestamp('2022-06-22 22:00:00'),
#  Timestamp('2022-06-22 23:00:00'),
#  Timestamp('2022-06-23 00:00:00'),
#  Timestamp('2022-06-23 01:00:00'),
#  Timestamp('2022-06-23 02:00:00'),
#  Timestamp('2022-06-23 03:00:00'),
#  Timestamp('2022-06-23 04:00:00'),
#  Timestamp('2022-06-23 05:00:00'),
#  Timestamp('2022-06-23 06:00:00'),
#  Timestamp('2022-06-23 07:00:00'),
#  Timestamp('2022-06-23 08:00:00'),
#  Timestamp('2022-06-23 09:00:00'),
#  Timestamp('2022-06-23 10:00:00'),
#  Timestamp('2022-06-23 11:00:00'),
#  Timestamp('2022-06-23 12:00:00'),
#  Timestamp('2022-06-23 13:00:00'),
#  Timestamp('2022-06-23 14:00:00'),
#  Timestamp('2022-06-23 15:00:00'),
#  Timestamp('2022-06-23 16:00:00'),
#  Timestamp('2022-06-23 17:00:00'),
#  Timestamp('2022-06-23 18:00:00'),
#  Timestamp('2022-06-23 19:00:00'),
#  Timestamp('2022-06-23 20:00:00'),
#  Timestamp('2022-06-23 21:00:00'),
#  Timestamp('2022-06-23 22:00:00'),
#  Timestamp('2022-06-23 23:00:00'),
#  Timestamp('2022-06-24 00:00:00'),
#  Timestamp('2022-06-24 01:00:00'),
#  Timestamp('2022-06-24 02:00:00'),
#  Timestamp('2022-06-24 03:00:00'),
#  Timestamp('2022-06-24 04:00:00'),
#  Timestamp('2022-06-24 05:00:00'),
#  Timestamp('2022-06-24 06:00:00'),
#  Timestamp('2022-06-24 07:00:00'),
#  Timestamp('2022-06-24 08:00:00'),
#  Timestamp('2022-06-24 09:00:00'),
#  Timestamp('2022-06-24 10:00:00'),
#  Timestamp('2022-06-24 11:00:00'),
#  Timestamp('2022-06-24 12:00:00'),
#  Timestamp('2022-06-24 13:00:00'),
#  Timestamp('2022-06-24 14:00:00'),
#  Timestamp('2022-06-24 15:00:00'),
#  Timestamp('2022-06-24 16:00:00'),
#  Timestamp('2022-06-24 17:00:00'),
#  Timestamp('2022-06-24 18:00:00'),
#  Timestamp('2022-06-24 19:00:00'),
#  Timestamp('2022-06-24 20:00:00'),
#  Timestamp('2022-06-24 21:00:00'),
#  Timestamp('2022-06-24 22:00:00'),
#  Timestamp('2022-06-24 23:00:00'),
#  Timestamp('2022-06-25 00:00:00'),
#  Timestamp('2022-06-25 01:00:00'),
#  Timestamp('2022-06-25 02:00:00'),
#  Timestamp('2022-06-25 03:00:00'),
#  Timestamp('2022-06-25 04:00:00'),
#  Timestamp('2022-06-25 05:00:00'),
#  Timestamp('2022-06-25 06:00:00'),
#  Timestamp('2022-06-25 07:00:00'),
#  Timestamp('2022-06-25 08:00:00'),
#  Timestamp('2022-06-25 09:00:00'),
#  Timestamp('2022-06-25 10:00:00'),
#  Timestamp('2022-06-25 11:00:00'),
#  Timestamp('2022-06-25 12:00:00'),
#  Timestamp('2022-06-25 13:00:00'),
#  Timestamp('2022-06-25 14:00:00'),
#  Timestamp('2022-06-25 15:00:00'),
#  Timestamp('2022-06-25 16:00:00'),
#  Timestamp('2022-06-25 17:00:00'),
#  Timestamp('2022-06-25 18:00:00'),
#  Timestamp('2022-06-25 19:00:00'),
#  Timestamp('2022-06-25 20:00:00'),
#  Timestamp('2022-06-25 21:00:00'),
#  Timestamp('2022-06-25 22:00:00'),
#  Timestamp('2022-06-25 23:00:00'),
#  Timestamp('2022-06-26 00:00:00'),
#  Timestamp('2022-06-26 01:00:00'),
#  Timestamp('2022-06-26 02:00:00'),
#  Timestamp('2022-06-26 03:00:00'),
#  Timestamp('2022-06-26 04:00:00'),
#  Timestamp('2022-06-26 05:00:00'),
#  Timestamp('2022-06-26 06:00:00'),
#  Timestamp('2022-06-26 07:00:00'),
#  Timestamp('2022-06-26 08:00:00'),
#  Timestamp('2022-06-26 09:00:00'),
#  Timestamp('2022-06-26 10:00:00'),
#  Timestamp('2022-06-26 11:00:00'),
#  Timestamp('2022-06-26 12:00:00'),
#  Timestamp('2022-06-26 13:00:00'),
#  Timestamp('2022-06-26 14:00:00'),
#  Timestamp('2022-06-26 15:00:00'),
#  Timestamp('2022-06-26 16:00:00'),
#  Timestamp('2022-06-26 17:00:00'),
#  Timestamp('2022-06-26 18:00:00'),
#  Timestamp('2022-06-26 19:00:00'),
#  Timestamp('2022-06-26 20:00:00'),
#  Timestamp('2022-06-26 21:00:00'),
#  Timestamp('2022-06-26 22:00:00'),
#  Timestamp('2022-06-26 23:00:00'),
#  Timestamp('2022-06-27 00:00:00'),
#  Timestamp('2022-06-27 01:00:00'),
#  Timestamp('2022-06-27 02:00:00'),
#  Timestamp('2022-06-27 03:00:00'),
#  Timestamp('2022-06-27 04:00:00'),
#  Timestamp('2022-06-27 05:00:00'),
#  Timestamp('2022-06-27 06:00:00'),
#  Timestamp('2022-06-27 07:00:00'),
#  Timestamp('2022-06-27 08:00:00'),
#  Timestamp('2022-06-27 09:00:00'),
#  Timestamp('2022-06-27 10:00:00'),
#  Timestamp('2022-06-27 11:00:00'),
#  Timestamp('2022-06-27 12:00:00'),
#  Timestamp('2022-06-27 13:00:00'),
#  Timestamp('2022-06-27 14:00:00'),
#  Timestamp('2022-06-27 15:00:00'),
#  Timestamp('2022-06-27 16:00:00'),
#  Timestamp('2022-06-27 17:00:00'),
#  Timestamp('2022-06-27 18:00:00'),
#  Timestamp('2022-06-27 19:00:00'),
#  Timestamp('2022-06-27 20:00:00'),
#  Timestamp('2022-06-27 21:00:00'),
#  Timestamp('2022-06-27 22:00:00'),
#  Timestamp('2022-06-27 23:00:00'),
#  Timestamp('2022-06-28 00:00:00'),
#  Timestamp('2022-06-28 01:00:00'),
#  Timestamp('2022-06-28 02:00:00'),
#  Timestamp('2022-06-28 03:00:00'),
#  Timestamp('2022-06-28 04:00:00'),
#  Timestamp('2022-06-28 05:00:00'),
#  Timestamp('2022-06-28 06:00:00'),
#  Timestamp('2022-06-28 07:00:00'),
#  Timestamp('2022-06-28 08:00:00'),
#  Timestamp('2022-06-28 09:00:00'),
#  Timestamp('2022-06-28 10:00:00'),
#  Timestamp('2022-06-28 11:00:00'),
#  Timestamp('2022-06-28 12:00:00'),
#  Timestamp('2022-06-28 13:00:00'),
#  Timestamp('2022-06-28 14:00:00'),
#  Timestamp('2022-06-28 15:00:00'),
#  Timestamp('2022-06-28 16:00:00'),
#  Timestamp('2022-06-28 17:00:00'),
#  Timestamp('2022-06-28 18:00:00'),
#  Timestamp('2022-06-28 19:00:00'),
#  Timestamp('2022-06-28 20:00:00'),
#  Timestamp('2022-06-28 21:00:00'),
#  Timestamp('2022-06-28 22:00:00'),
#  Timestamp('2022-06-28 23:00:00'),
#  Timestamp('2022-06-29 00:00:00'),
#  Timestamp('2022-06-29 01:00:00'),
#  Timestamp('2022-06-29 02:00:00'),
#  Timestamp('2022-06-29 03:00:00'),
#  Timestamp('2022-06-29 04:00:00'),
#  Timestamp('2022-06-29 05:00:00'),
#  Timestamp('2022-06-29 06:00:00'),
#  Timestamp('2022-06-29 07:00:00'),
#  Timestamp('2022-06-29 08:00:00'),
#  Timestamp('2022-06-29 09:00:00'),
#  Timestamp('2022-06-29 10:00:00'),
#  Timestamp('2022-06-29 11:00:00'),
#  Timestamp('2022-06-29 12:00:00'),
#  Timestamp('2022-06-29 13:00:00'),
#  Timestamp('2022-06-29 14:00:00'),
#  Timestamp('2022-06-29 15:00:00'),
#  Timestamp('2022-06-29 16:00:00'),
#  Timestamp('2022-06-29 17:00:00'),
#  Timestamp('2022-06-29 18:00:00'),
#  Timestamp('2022-06-29 19:00:00'),
#  Timestamp('2022-06-29 20:00:00'),
#  Timestamp('2022-06-29 21:00:00'),
#  Timestamp('2022-06-29 22:00:00'),
#  Timestamp('2022-06-29 23:00:00'),
#  Timestamp('2022-06-30 00:00:00'),
#  Timestamp('2022-06-30 01:00:00'),
#  Timestamp('2022-06-30 02:00:00'),
#  Timestamp('2022-06-30 03:00:00'),
#  Timestamp('2022-06-30 04:00:00'),
#  Timestamp('2022-06-30 05:00:00'),
#  Timestamp('2022-06-30 06:00:00'),
#  Timestamp('2022-06-30 07:00:00'),
#  Timestamp('2022-06-30 08:00:00'),
#  Timestamp('2022-06-30 09:00:00'),
#  Timestamp('2022-06-30 10:00:00'),
#  Timestamp('2022-06-30 11:00:00'),
#  Timestamp('2022-06-30 12:00:00'),
#  Timestamp('2022-06-30 13:00:00'),
#  Timestamp('2022-06-30 14:00:00'),
#  Timestamp('2022-06-30 15:00:00'),
#  Timestamp('2022-06-30 16:00:00'),
#  Timestamp('2022-06-30 17:00:00'),
#  Timestamp('2022-06-30 18:00:00'),
#  Timestamp('2022-06-30 19:00:00'),
#  Timestamp('2022-06-30 20:00:00'),
#  Timestamp('2022-06-30 21:00:00'),
#  Timestamp('2022-06-30 22:00:00'),
#  Timestamp('2022-06-30 23:00:00'),
#  Timestamp('2022-07-01 00:00:00'),
#  Timestamp('2022-07-01 01:00:00'),
#  Timestamp('2022-07-01 02:00:00'),
#  Timestamp('2023-03-01 00:00:00'),
#  Timestamp('2023-03-01 01:00:00'),
#  Timestamp('2023-03-01 02:00:00'),
#  Timestamp('2023-11-12 00:00:00'),
#  Timestamp('2023-11-12 01:00:00'),
#  Timestamp('2023-11-12 02:00:00'),
#  Timestamp('2023-11-12 03:00:00'),
#  Timestamp('2023-11-12 04:00:00'),
#  Timestamp('2023-11-12 05:00:00'),
#  Timestamp('2023-11-12 06:00:00'),
#  Timestamp('2023-11-12 07:00:00'),
#  Timestamp('2023-11-12 08:00:00'),
#  Timestamp('2024-01-03 00:00:00'),
#  Timestamp('2024-01-03 01:00:00'),
#  Timestamp('2024-01-03 02:00:00'),
#  Timestamp('2024-01-03 03:00:00'),
#  Timestamp('2024-01-03 04:00:00'),
#  Timestamp('2024-01-03 05:00:00'),
#  Timestamp('2024-01-03 06:00:00'),
#  Timestamp('2024-01-03 07:00:00'),
#  Timestamp('2024-01-03 08:00:00')}

# %% [markdown]
# ## Turns out these hours are available...
# ### Need to investiage further:
# 1. Do we need to use these downloaded files in the IDX conversion because somehow we didn't already download them?
# 2. Or, do we already have the files and we instead sequenced through the netCDF files incorrectly...

# %% [markdown]
# ### 1. Let's see if the files we downloaded are all available in the files we originally downloaded...
# We will check if they open successfully as well. Otherwise we should redownload failed files.

# %%
# Get directory to where we downloaded netCDF for IDX conversion

# ******* THIS IS WHEN RUNNING FROM ATLANTIS.SCI **************
firesmoke_dir = "/usr/sci/cedmav/data/firesmoke"

print(f'downloaded netCDF data for IDX conversions at\n {firesmoke_dir}')
print(f'downloaded netCDF data for diagnosing issues at\n {garbage}')
# Out:
# downloaded netCDF data for IDX conversions at
#  /usr/sci/cedmav/data/firesmoke
# downloaded netCDF data for diagnosing issues at
#  /usr/sci/scratch_nvme/arleth/total_garbage

# %% [markdown]
# #### For each file we downloaded and successfully opened at `garbage` dir, see if it exists in the `firesmoke_dir`

# %%
# to keep track of successful_files we downloaded for IDX conversion already
idx_successful_files = {id_: [] for id_ in ids}
idx_new_hours = set()

# to track what files failed and WHY, that way we know WHAT files to 'fix'
idx_failed_files = {id_: [] for id_ in ids}

# for each dataset
for id_ in ids:
    # for each file downloaded for said dataset
    for file in successful_files[id_]:
        # get file name
        file_name = file[-len('dispersion_20220616.nc'):]
        # get path to netCDF file that may be in IDX netCDF downloads
        idx_file_path = f'{firesmoke_dir}/{id_}/{file_name}'
        
        # keep track of which files successfully open
        try:
            # open the file with xarray
            ds = xr.open_dataset(idx_file_path)

            # append file name to successful_files
            idx_successful_files[id_].append(file_name)

            # add each available hour to idx_new_hours
            for h in range(ds.sizes["TSTEP"]):
                vals = ds['TFLAG'].values[h]
                curr_tflag = parse_tflag(ds['TFLAG'].values[h][0])
                panda_tflag = pd.Timestamp(curr_tflag)
                idx_new_hours.add((id_, panda_tflag))
        # ref: https://stackoverflow.com/questions/9823936/how-do-i-determine-what-type-of-exception-occurred
        except Exception as e:
            # if file cannot be opened by xarray
            if 'did not find a match in any of xarray' in str(e):
                idx_failed_files[id_].append((file_name, 'INCOMPATIBLE FILE'))
            # if file isn't found
            elif 'No such file or directory' in str(e):
                idx_failed_files[id_].append((file_name, 'NO SUCH FILE'))
            else:
            # otherwise... who knows check issue
                idx_failed_files[id_].append((file_name, str(e)))
            continue

# %%
idx_failed_files
# Out:
# {'BSC18CA12-01': [('dispersion_20220630.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220606.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220603.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220610.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220624.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220604.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220619.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220613.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210228.nc', 'NO SUCH FILE'),
#   ('dispersion_20220621.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220627.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220628.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220607.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220609.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220626.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210301.nc', 'NO SUCH FILE'),
#   ('dispersion_20220620.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220629.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220605.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220617.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220602.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220618.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220601.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220625.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220611.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220622.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220615.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210302.nc', 'NO SUCH FILE'),
#   ('dispersion_20220623.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220616.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220608.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220614.nc', 'INCOMPATIBLE FILE')],
#  'BSC00CA12-01': [('dispersion_20220605.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220615.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220626.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220603.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220611.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220606.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220604.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220623.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220624.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220608.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220630.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220601.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220620.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220610.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220621.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220607.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210301.nc', 'NO SUCH FILE'),
#   ('dispersion_20220602.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210303.nc', 'NO SUCH FILE'),
#   ('dispersion_20220613.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220612.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220616.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220629.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220619.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220617.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220614.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220627.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210228.nc', 'NO SUCH FILE'),
#   ('dispersion_20220628.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220618.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220609.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220622.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220625.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210302.nc', 'NO SUCH FILE')],
#  'BSC06CA12-01': [('dispersion_20220614.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220629.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220607.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220610.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220625.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220622.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220603.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220619.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220617.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220626.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220601.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220608.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210302.nc', 'NO SUCH FILE'),
#   ('dispersion_20220627.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220611.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220602.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220628.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220615.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220604.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220620.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220609.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210301.nc', 'NO SUCH FILE'),
#   ('dispersion_20220612.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220618.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220605.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220630.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210228.nc', 'NO SUCH FILE'),
#   ('dispersion_20220621.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220613.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220606.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220616.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210303.nc', 'NO SUCH FILE'),
#   ('dispersion_20220623.nc', 'INCOMPATIBLE FILE')],
#  'BSC12CA12-01': [('dispersion_20220629.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220614.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220607.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220617.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220627.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220601.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220616.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220620.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220608.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220618.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220630.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220622.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220615.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220604.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220626.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220612.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220624.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220619.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220625.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220610.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220606.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220605.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220603.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220613.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210228.nc', 'NO SUCH FILE'),
#   ('dispersion_20220609.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220623.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210301.nc', 'NO SUCH FILE'),
#   ('dispersion_20220628.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220602.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20220621.nc', 'INCOMPATIBLE FILE'),
#   ('dispersion_20210302.nc', 'NO SUCH FILE')]}

# %%
for id_ in ids:
    print(f'For {id_}')
    print(f'Of {len(successful_files[id_])} newly downloaded, there are {len(idx_successful_files[id_])} files for idx conversion.')
# Out:
# For BSC18CA12-01
# Of 41 newly downloaded, there are 9 files for idx conversion.
# For BSC00CA12-01
# Of 49 newly downloaded, there are 15 files for idx conversion.
# For BSC06CA12-01
# Of 42 newly downloaded, there are 9 files for idx conversion.
# For BSC12CA12-01
# Of 40 newly downloaded, there are 8 files for idx conversion.

# %% [markdown]
# #### For reference future reference, I got the following output:
# ```
# For BSC18CA12-01
# Of 41 newly downloaded, there are 9 files for idx conversion.
# For BSC00CA12-01
# Of 49 newly downloaded, there are 15 files for idx conversion.
# For BSC06CA12-01
# Of 42 newly downloaded, there are 9 files for idx conversion.
# For BSC12CA12-01
# Of 40 newly downloaded, there are 8 files for idx conversion.
# ```
#
# Great, so we should redo the IDX conversion and add these newly downloaded netCDFs to fill in the gaps!

# %% [markdown]
# #### Wait but what about files that successfully open, do they hold any of the hours we are missing...

# %%
# get all timestamps downloaded
idx_hours_set = set()

# get each timestamp, add it to a set
for hour in idx_new_hours:
    idx_hours_set.add(hour[1])

print(f'len(idx_new_hours.intersection(missing_tflags)) = {len(idx_new_hours.intersection(missing_tflags))}')
# Out:
# len(idx_new_hours.intersection(missing_tflags)) = 0

# %% [markdown]
# #### `len(idx_new_hours.intersection(missing_tflags)) = 0`
# #### So now we know to fix the missing 747 hours we must add the newly downloaded netCDF files to the set of netCDF files used during IDX conversion.
#
# We must have failed to download those files initially.

# %% [markdown]
# go ahead and delete all files from the `firesmoke_dir` that are listed as `successful_files` here. then copy paste `successful_files` to corresponding `firesmoke_dir`, then we're ready to redo conversion........

# %%
# delete files from firesmoke_dir, we will replace them next...
for id_ in ids:
    for f in successful_files[id_]:
        to_delete = f'{firesmoke_dir}/{f[-len("BSC18CA12-01/dispersion_20220630.nc"):]}'
        # try deleting the file
        try:
            # ref: https://stackoverflow.com/questions/6996603/how-can-i-delete-a-file-or-folder-in-python
            os.remove(to_delete)
        # catch exception, likely from 'no such file or directory'
        except Exception as e:
            print(e)
# Out:
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC18CA12-01/dispersion_20210228.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC18CA12-01/dispersion_20210301.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC18CA12-01/dispersion_20210302.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC00CA12-01/dispersion_20210301.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC00CA12-01/dispersion_20210303.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC00CA12-01/dispersion_20210228.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC00CA12-01/dispersion_20210302.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC06CA12-01/dispersion_20210302.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC06CA12-01/dispersion_20210301.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC06CA12-01/dispersion_20210228.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC06CA12-01/dispersion_20210303.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC12CA12-01/dispersion_20210228.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC12CA12-01/dispersion_20210301.nc'
# [Errno 2] No such file or directory: '/usr/sci/cedmav/data/firesmoke/BSC12CA12-01/dispersion_20210302.nc'

# %% [markdown]
# now add newly downloaded files to the firesmoke dir accordingly

# %%
# # move files to firesmoke_dir
# # ref: https://stackoverflow.com/questions/123198/how-to-copy-files
# for id_ in ids:
#     for f in successful_files[id_]:
#         move_to_dir = f'{firesmoke_dir}/{f[-len("BSC18CA12-01/dispersion_20220630.nc"):]}'
#         shutil.copyfile(f, move_to_dir)
#         # print(f'MOVING {f} TO {move_to_dir}')
