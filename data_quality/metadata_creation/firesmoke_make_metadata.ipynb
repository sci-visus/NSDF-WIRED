# %% [markdown]
# # Here we're making arrays holding metadata for idx conversion v4
# ## In particular we get:
# - Timestamp of each datum
# - Boolean representing if datum was resampled from 1041x381 to 1081x381 grid
# - Timestamp of each datum's last [WRF-ARW weather forecast initialization](https://firesmoke.ca/resources/BSC-2015ForecastScheduleV6.pdf)

# %% [markdown]
# ## Import necessary libraries

# %%
# Used to read/manipulate netCDF data
import xarray as xr

# Used for interacting with OS file system (to get directory file names)
import os

# Used for processing netCDF time data
import time
import datetime

# Used for numerical work
import numpy as np

# Used for loading data from pickle data
import pickle

# Accessory for generating progress bar to see progress of loops
from tqdm import tqdm

# %% [markdown]
# ## Import sequence of IDX calls

# %%
# copy and paste .pkl file into working directory
with open("idx_calls_v4.pkl", "rb") as input_file:
    idx_calls = pickle.load(input_file)

# %%
idx_calls
# Out:
# [['BSC12CA12-01',
#   'dispersion_20210303.nc',
#   datetime.datetime(2021, 3, 4, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210303.nc',
#   datetime.datetime(2021, 3, 4, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210303.nc',
#   datetime.datetime(2021, 3, 4, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 4, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210303.nc',
#   datetime.datetime(2021, 3, 4, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210303.nc',
#   datetime.datetime(2021, 3, 4, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210303.nc',
#   datetime.datetime(2021, 3, 4, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 5, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 5, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 5, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 5, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 5, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 5, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210304.nc',
#   datetime.datetime(2021, 3, 5, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 6, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 6, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 6, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 6, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 6, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 6, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210305.nc',
#   datetime.datetime(2021, 3, 6, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 7, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 7, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 7, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 7, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 7, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 7, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210306.nc',
#   datetime.datetime(2021, 3, 7, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 8, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 8, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 8, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 14, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 15, 0),
#   6],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 16, 0),
#   7],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 17, 0),
#   8],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 18, 0),
#   9],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 19, 0),
#   10],
#  ['BSC00CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 8, 20, 0),
#   11],
#  ['BSC12CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 8, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 8, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210307.nc',
#   datetime.datetime(2021, 3, 8, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 9, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 9, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 9, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210309.nc',
#   datetime.datetime(2021, 3, 9, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 9, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 9, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 9, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 10, 0, 0),
#   27],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 10, 1, 0),
#   28],
#  ['BSC12CA12-01',
#   'dispersion_20210308.nc',
#   datetime.datetime(2021, 3, 10, 2, 0),
#   29],
#  ['BSC18CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 20, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 21, 0),
#   6],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 22, 0),
#   7],
#  ['BSC06CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 10, 23, 0),
#   8],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 2, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 3, 0),
#   6],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 4, 0),
#   7],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 5, 0),
#   8],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 6, 0),
#   9],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 7, 0),
#   10],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 8, 0),
#   11],
#  ['BSC00CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 11, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210310.nc',
#   datetime.datetime(2021, 3, 11, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 12, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 12, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 12, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 12, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 12, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 12, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210311.nc',
#   datetime.datetime(2021, 3, 12, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 13, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 13, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 13, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 13, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 13, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 13, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210312.nc',
#   datetime.datetime(2021, 3, 13, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 14, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 14, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 14, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 14, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 14, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 14, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210313.nc',
#   datetime.datetime(2021, 3, 14, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 15, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 15, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 15, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 15, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 15, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 15, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210314.nc',
#   datetime.datetime(2021, 3, 15, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 16, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 16, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 16, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 16, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 16, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 16, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210315.nc',
#   datetime.datetime(2021, 3, 16, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 17, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 17, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 17, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 17, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 17, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 17, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210316.nc',
#   datetime.datetime(2021, 3, 17, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 18, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 18, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 18, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 18, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 18, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 18, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210317.nc',
#   datetime.datetime(2021, 3, 18, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 19, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 19, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 19, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 19, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 19, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 19, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210318.nc',
#   datetime.datetime(2021, 3, 19, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 20, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 20, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 20, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 20, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 20, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 20, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210319.nc',
#   datetime.datetime(2021, 3, 20, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 21, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 21, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 21, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 21, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 21, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 21, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210320.nc',
#   datetime.datetime(2021, 3, 21, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 22, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 22, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 22, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 22, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 22, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 22, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210321.nc',
#   datetime.datetime(2021, 3, 22, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 23, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 23, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 23, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 23, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 23, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 23, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210322.nc',
#   datetime.datetime(2021, 3, 23, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 24, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 24, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 24, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 24, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 24, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 24, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210323.nc',
#   datetime.datetime(2021, 3, 24, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 25, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 25, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210324.nc',
#   datetime.datetime(2021, 3, 25, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210325.nc',
#   datetime.datetime(2021, 3, 25, 14, 0),
#   5],
#  ['BSC06CA12-01',
# ...
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 14, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 15, 0),
#   6],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 16, 0),
#   7],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 17, 0),
#   8],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 18, 0),
#   9],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 19, 0),
#   10],
#  ['BSC00CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 7, 20, 0),
#   11],
#  ['BSC12CA12-01',
#   'dispersion_20210406.nc',
#   datetime.datetime(2021, 4, 7, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210406.nc',
#   datetime.datetime(2021, 4, 7, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210406.nc',
#   datetime.datetime(2021, 4, 7, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 8, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 8, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 8, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 8, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 8, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 8, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210407.nc',
#   datetime.datetime(2021, 4, 8, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 9, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 9, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 9, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 9, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 9, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 9, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210408.nc',
#   datetime.datetime(2021, 4, 9, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 10, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 10, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 10, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 10, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 10, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 10, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210409.nc',
#   datetime.datetime(2021, 4, 10, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 2, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 3, 0),
#   6],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 4, 0),
#   7],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 5, 0),
#   8],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 6, 0),
#   9],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 7, 0),
#   10],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 8, 0),
#   11],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 14, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 15, 0),
#   6],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 16, 0),
#   7],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 17, 0),
#   8],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 18, 0),
#   9],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 19, 0),
#   10],
#  ['BSC00CA12-01',
#   'dispersion_20210411.nc',
#   datetime.datetime(2021, 4, 11, 20, 0),
#   11],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 11, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 12, 0, 0),
#   27],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 12, 1, 0),
#   28],
#  ['BSC12CA12-01',
#   'dispersion_20210410.nc',
#   datetime.datetime(2021, 4, 12, 2, 0),
#   29],
#  ['BSC18CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 20, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 21, 0),
#   6],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 22, 0),
#   7],
#  ['BSC06CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 12, 23, 0),
#   8],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 13, 0, 0),
#   3],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 13, 1, 0),
#   4],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 13, 2, 0),
#   5],
#  ['BSC18CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 15, 0),
#   0],
#  ['BSC06CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 16, 0),
#   1],
#  ['BSC06CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 17, 0),
#   2],
#  ['BSC06CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 18, 0),
#   3],
#  ['BSC06CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 19, 0),
#   4],
#  ['BSC06CA12-01',
#   'dispersion_20210413.nc',
#   datetime.datetime(2021, 4, 13, 20, 0),
#   5],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 13, 21, 0),
#   24],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 13, 22, 0),
#   25],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 13, 23, 0),
#   26],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 14, 0, 0),
#   27],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 14, 1, 0),
#   28],
#  ['BSC12CA12-01',
#   'dispersion_20210412.nc',
#   datetime.datetime(2021, 4, 14, 2, 0),
#   29],
#  ['BSC18CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 3, 0),
#   0],
#  ['BSC18CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 4, 0),
#   1],
#  ['BSC18CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 5, 0),
#   2],
#  ['BSC18CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 6, 0),
#   3],
#  ['BSC18CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 7, 0),
#   4],
#  ['BSC18CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 8, 0),
#   5],
#  ['BSC00CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 9, 0),
#   0],
#  ['BSC00CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 10, 0),
#   1],
#  ['BSC00CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 11, 0),
#   2],
#  ['BSC00CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 12, 0),
#   3],
#  ['BSC00CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 13, 0),
#   4],
#  ['BSC00CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 14, 0),
#   5],
#  ['BSC06CA12-01',
#   'dispersion_20210414.nc',
#   datetime.datetime(2021, 4, 14, 15, 0),
#   0],
#  ...]

# %% [markdown]
# Location of all netCDF files

# %%
# location of netCDF files
firesmoke_dir = "/usr/sci/cedmav/data/firesmoke"

# %% [markdown]
# ## Step through all `idx_calls` and obtain metadata.
#
# ### Specifically we:
# 1. Get timestamps as saved in `idx_calls`.
# 2. Get grid size from original netCDF files.
# 3. Get last initialized time as shown in `idx_calls`.
# ---
# These instructions could have been run during the IDX conversion. However I decided to do it separately by stepping through the `idx_calls` sequence so the IDX conversion loop would not be so bloated.

# %%
# obtaining the preferred tflag based on original metadata
def reverse_parse_tflag(full_datetime):
    '''
    Return the UBC style tflag for given datetime stamp
    :param datetime full_datetime: full datetime object containing the year, day, hour, minute, and second
    :return: tuple containing two tflags, where the first represents the year and day of the year,
             and the second represents the hour, minute, and second
    '''
    year = full_datetime.year
    day_of_year = full_datetime.timetuple().tm_yday
    hours = full_datetime.hour
    minutes = full_datetime.minute
    seconds = full_datetime.second

    tflag0 = year * 1000 + day_of_year
    tflag1 = hours * 10000 + minutes * 100 + seconds

    return tflag0, tflag1

# %%
def get_last_timestamp(id_, file):
    '''
    Return datetime stamp of the last forecast update seen for the given dataset ID and file name.
    :param str id_: The dataset ID used
    :param str file: The name of the file, with the date
    '''
    # use file's date
    date = datetime.datetime.strptime(file[-len('20210304.nc'):-len('.nc')], "%Y%m%d")
    
    # set hour of intialization based on dataset ID
    if id_ == "BSC18CA12-01":
        date = date.replace(hour=18)
    if id_ == "BSC00CA12-01": 
        date = date.replace(hour=0)
    if id_ == "BSC06CA12-01":
        date = date.replace(hour=6)
    if id_ == "BSC12CA12-01":
        date = date.replace(hour=12)
    return date

# %%
# the final array of UBC style tflags
tflags = []

# whether resampled or not
is_resampled = []

# hold the timestamp of when each timestamp saw it's last forecast initialization
last_init = []

# hold the attributes for each file, TODO NEED TO CONFIRM WHAT THEY ARE?, SEEMS USEFUL ATTRS
attrs_desired = ['CDATE', 'CTIME', 'WDATE', 'WTIME', 'SDATE', 'STIME']

attr_data = {attr: [] for attr in attrs_desired}

# create array of UBC style tflags from our sequence of idx_calls
for call in tqdm(idx_calls):
    # get instructions from call, call looks like:
    # [curr_id, file_str, parse_tflag(ds['TFLAG'].values[tstep_idx][0]), tstep_idx]
    curr_id = call[0]
    curr_file = call[1]
    curr_tflag = call[2]
    tstep_index = call[3]    

    # open the file with xarray
    ds = xr.open_dataset(f'{firesmoke_dir}/{curr_id}/{curr_file}')
    
    # resample data if not already on max lat/lon grid
    is_resampled.append(ds.XORIG != -160.0)

    # make UBC style tflag and append to our final array
    tflags.append(reverse_parse_tflag(curr_tflag))

    # get UBC style tflag of last forecast update time
    last_timestamp = get_last_timestamp(curr_id, curr_file)
    last_init.append(reverse_parse_tflag(last_timestamp))
    
    # save the attribute information to the arrays
    for attr in attrs_desired:
        attr_data[attr].append(ds.attrs[attr])
# Out:
# 100%|██████████| 27357/27357 [05:10<00:00, 88.07it/s]

# %%
# save all arrays, the metadata
np.save('firesmoke_v4-tflags.npy', tflags)
np.save('firesmoke_v4-resamp.npy', is_resampled)
np.save('firesmoke_v4-last_init.npy', last_init)

for attr in attrs_desired:
    np.save(f'firesmoke_v4-{attr}.npy', attr_data[attr])
